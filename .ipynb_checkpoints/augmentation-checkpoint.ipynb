# %%
import pandas as pd
from BERT_augmentation import BERT_Augmentation
from adverb_augmentation import AdverbAugmentation

# %%
BERT_aug = BERT_Augmentation()
random_masking_replacement = BERT_aug.random_masking_replacement
random_masking_insertion = BERT_aug.random_masking_insertion

# %%
adverb_aug = AdverbAugmentation()
adverb_gloss_replacement = adverb_aug.adverb_gloss_replacement

# %%
# dataset
orig_train = pd.read_json('sts/datasets/klue-sts-v1.1_train.json')
orig_train.head(2)
# Out:
#                       guid          source  \
# 0  klue-sts-v1_train_00000      airbnb-rtt
# 1  klue-sts-v1_train_00001  policy-sampled
#
#                                        sentence1  \
# 0               숙소 위치는 찾기 쉽고 일반적인 한국의 반지하 숙소입니다.
# 1  위반행위 조사 등을 거부·방해·기피한 자는 500만원 이하 과태료 부과 대상이다.
#
#                                     sentence2  \
# 0  숙박시설의 위치는 쉽게 찾을 수 있고 한국의 대표적인 반지하 숙박시설입니다.
# 1       시민들 스스로 자발적인 예방 노력을 한 것은 아산 뿐만이 아니었다.
#
#                                               labels  \
# 0  {'label': 3.7, 'real-label': 3.714285714285714...
# 1  {'label': 0.0, 'real-label': 0.0, 'binary-labe...
#
#                                          annotations
# 0  {'agreement': '0:0:0:2:5:0', 'annotators': ['0...
# 1  {'agreement': '5:0:0:0:0:0', 'annotators': ['1...

# %%
len(orig_train)
# Out:
# 11668

# %% [markdown]
# Augmentation 방법
# - 원본 + sentence1만 변형한 set + sentence2만 변형한 set.

# %%
sen1_random_masking_replacement_train = orig_train.copy()
sen2_random_masking_replacement_train = orig_train.copy()
sen1_random_masking_replacement_train['sentence1'] = sen1_random_masking_replacement_train['sentence1'].apply(lambda x: random_masking_replacement(x, span=1))
sen2_random_masking_replacement_train['sentence2'] = sen2_random_masking_replacement_train['sentence2'].apply(lambda x: random_masking_replacement(x, span=1))

# %%
random_masking_replacement_augset = pd.concat([orig_train, sen1_random_masking_replacement_train, sen2_random_masking_replacement_train])
random_masking_replacement_augset.drop_duplicates(['sentence1', 'sentence2'], inplace=True)
len(random_masking_replacement_augset)
# Out:
# 32941

# %%
random_masking_replacement_augset.reset_index().to_json('sts/datasets/klue-sts-v1.1_train_random_masking_replacement_augset.json')

# %%
sen1_random_masking_insertion_train = orig_train.copy()
sen2_random_masking_insertion_train = orig_train.copy()
sen1_random_masking_insertion_train['sentence1'] = sen1_random_masking_insertion_train['sentence1'].apply(lambda x: random_masking_insertion(x))
sen2_random_masking_insertion_train['sentence2'] = sen2_random_masking_insertion_train['sentence2'].apply(lambda x: random_masking_insertion(x))

# %%
random_masking_insertion_augset = pd.concat([orig_train, sen1_random_masking_insertion_train, sen2_random_masking_insertion_train])
random_masking_insertion_augset.drop_duplicates(['sentence1', 'sentence2'], inplace=True)
len(random_masking_insertion_augset)
# Out:
# 33876

# %%
random_masking_insertion_augset.reset_index().to_json('sts/datasets/klue-sts-v1.1_train_random_masking_insertion_augset.json')

# %%
sen1_adverb_train = orig_train.copy()
sen2_adverb_train = orig_train.copy()
sen1_adverb_train['sentence1'] = sen1_adverb_train['sentence1'].apply(lambda x: adverb_gloss_replacement(x))
sen2_adverb_train['sentence2'] = sen2_adverb_train['sentence2'].apply(lambda x: adverb_gloss_replacement(x))
# Out:
# 숙소 위치는 찾기 쉽고 일반적인 한국의 반지하 숙소입니다.
# 위반행위 조사 등을 거부·방해·기피한 자는 500만원 이하 과태료 부과 대상이다.
# 회사가 보낸 메일은 이 지메일이 아니라 다른 지메일 계정으로 전달해줘.
# 긴급 고용안정지원금은 지역고용대응 등 특별지원금, 지자체별 소상공인 지원사업, 취업성공패키지, 청년구직활동지원금, 긴급복지지원제도 지원금과는 중복 수급이 불가능하다.
# 호스트의 답장이 늦으나, 개선될 것으로 보입니다.
# 정부가 새로운 일자리를 직접 창출하는 노력도 배가하겠습니다.
# 지하철을 타도 30분안에는 이동이 가능합니다!
# 사례집은 국립환경과학원 누리집(ecolibrary.me.go.kr)에서 12일부터 볼 수 있다.
# 환퐁기 작동 방법 좀 설명해줘
# 새로운 친구들을 만나고 싶을때 아주 추천합니다.
# 지금 칠월에 약속을 몇 개나 잡으셨는지 말쑴해 주실 수 있나요?
# 2층 부엌과 거실 시설도 굉장히 좋고 히터도 잘 작동합니다.
# 오후 4시쯤에 정원은 너무나 아름다웠어요!
# 다만 소파 침대에 얼룩과 먼지가 조금 있었습니다
# 앞으로 늦지 말고 회사 상사와 약속에는 먼저 나가야해.
# 신주쿠에서 딱 두 정거장 떨어진 히가시나카노 역에서 금방 갈 수 있구요
# 시끄러운 런던 중심가보다 훨씬 좋습니다.
# 시장에서 어떤 거 사오려고 하시나요?
# 에어컨 쓰면 안된다고 경고했어.
# 여행을 마치고 나서도 호스트와 체코가 생각이 납니다.
# 욕실 수압도 세고 따뜻한 물도 잘 나와요.
# 가급적 식사는 거르지 않도록 해라.
# 555조8000억원으로 편성한 내년도 예산안은 국난극복과 선도국가로 가기 위한 의지를 담았다는 것이 문 대통령의 설명이다.
# 방에 110볼트 컨버터 3개 있습니다.
# 샤워기도 수압이 너무 약해서 불편해요.
# 그리고 숙소가 예뻐요 그냥 너무너무 예뻐요.
# 유럽연합(EU) 등에서 사용 중인 녹색금융의 개념과 분류기준 등을 참고해 우리나라 실정에 맞는 한국형 녹색금융 분류체계를 마련, 보급한다.
# 영하일까? 영상일까? 내일 기온은.
# 한편 이날 행사 이후 제주에너지공사, 한국중부발전, 현대자동차, 수소융합얼라이언스추진단 등 4개 기관은 ‘제주 그린수소 전주기 실증 프로젝트를 위한 업무협약’을 체결했다.
# 다만 흡연자가 많이 있어 비흡연자가 식사하기에 어려울 수 있는 것을 참고하세요.
# 어린이 장화의 가격은?
# 특히 ‘유전자 증폭방식’ 검사결과는 작업 과정의 작은 차이에도 영향을 받을 수 있어 이번 국제표준 제정이 코로나19 등 감염병 진단검사의 정확도 향상에 기여할 것으로 기대된다.
# 우리 경제의 현재와 미래에 대한 국내외 투자자들의 평가가 어느 때보다 긍정적이라는 것을 주가라는 객관적 지표로 확인하고 있는 것입니다.
# 위치, 청결, 가격, 호스트 모두 좋아요.
# 몽트뢰일정이길고여유로우신분들은꼭이집으로가세요.
# 2020년 1월말 기준 소금, 후추, 수프 스탁, 쌀, 티백이 있었어요.
# 이번 제5기 위원회는 국내 및 국제적으로 지식재산 연구·활동 경험이 풍부한 정상조 민간위원장을 포함, 주요 분야에서 전문 식견이 높은 위원 중심으로 구성됐다.
# 숙소의 위치나 청결도, 편리함 모두 만족스러웠습니다.
# 그래도 세탁기와 건조기 사용이 좋았어요
# 숙소는 도보로 오페라, 라파예트 등 주요관광지를 다니기에 부족함이 없었어요.
# 한낮에 내륙 중심은 몇 도 인가요?
# 다음 주에는 언제 비가 와?
# 부디 다음으로 호스팅을 할 때는 게스트를 보다 더 배려해주시길 바랍니다.
# 에어컨 짧게 쓰지 말고 한 번에 길게 틀어 놔.
# 좋은숙소를 이용할 수 있어서 감사합니다.
# 이번 전략은 지난 7월 한국판 디지털 뉴딜의 일환으로 인공지능·데이터 기반의 스마트제조 미래 청사진을 제시한 ‘스마트제조 2.0 전략’에 대한 후속 실행 전략이다.
# 다른 객실 인원은 조용했으나 바닥 소리가 큽니다.
# 더구나 샤워시 몸을 양 팔꿈치를 올리기 힘들정도의 좁은 공간이 나에게 고문 이었어요!
# 신속한 응답과 친절한 배려 모든부분에서 만족스러웠다.
# 한층에 룸이 5개씩, 총 10 개 정도인 것 같은데 한국의 고급 고시텔 느낌일까요.
# 마치 영화에 나오는 프랑스 장면들 같았어요.
# 그러니 싱글 방을 이용하시려는 분들은 1번방이 더 좋을 것 같아요.
# 화장실도 깨끗하고 따뜻한 물도 잘나와요.
# 호스트와의 연락은 전화번호나 메세지 보다 이메일이 가장 빠르고 정확합니다!
# 멜버른을 다시 방문하면 꼭 이숙소를 쓸것입니다.
# 정부는 연말까지 관광진흥법을 개정, 내국인 대상 도시민박 영업을 최대 180일 허용할 방침이다.
# 그 가까움을 더욱 가깝게 이어주는 우리 기업인 여러분들이 바로 그 신뢰를 키우는 주역입니다.
# 위치는 세비야 중심은 아니지만 세비야 대성당이나 알카사르 등 도보로 이동 가능합니다.
# 미세먼지 마스크 제조하는 업체는 어디입니까?
# 개선문과 샹젤리제 거리까지 걸어갈 수 있어요
# 네이트 메일이 지원하지 않는 첨부파일 종류는?
# 무료로 제공되는 네스프레소와 함께여는 포르투의 아침은 정말 최고였습니다.
# 담배연기 냄새가 심해서 아이들과 머물기 힘듭니다.
# 또한 숙소내부는 사진보다 훨씬 좋았습니다.
# 가족단위 투숙객들에게 특히 좋을 것 같습니다.
# 역에서 거리가 있지만 개인실에 편안한 공간입니다.
# 파리숙소들이 워낙 비싼데 나쁘지 않은가격에 쏘쏘한 집입니다.
# 그리고 항상 빠른 피드백을 주었습니다.
# 대학 후배 결혼식이니까 늦지 말거라.
# 당신의 트위치 계정은 트위터보다는 페이스북과 연동하는 것이 바람직합니다.
# 삼십도 이상은 안됩니다. 겨울철 실내온도.
# 위치와 청결, 시설은 정말 훌륭했습니다.
# 최근 거래처 메일에 가장 많이 출현한 단어는?
# 교통위치좋고 아침제공서비스및 청결,친절함
# 영화는 시간이 다되어서 취소기 보단 최소 하루 전에 취소하렴.
# 엘리베이터가 2인승 그것도 좀 큰 백팩이 있으면 한명밖에 못들어갑니다.
# 언제 놀러가실건가요, 금요일과 토요일 중에 골라주시겠습니까?
# 자원봉사 다음주 어느 시간으로 잡혔어?
# 우리 문화의 정체성과 다양성을 보존하기 위해 국어문화, 전통문화, 기초예술, 인디문화 등을 계속 지원한다.
# 이 부분은 피렌체 난방 정책상 어쩔수 없는 부분이라고 합니다.
# 호텔보다 더 좋은점은 올리브유, 소금, 식기구 등을 호스트가 제공한다는 점이에요!
# 집안에 그 조명등 있는거 밝기가 얼마나 되는지 어떻게 알 수 있죠
# 혹시 약속을 변경하실 때에는 그냥 변경하지 마시고 삼십분 전에 그 사유를 공지해주십시오.
# 너는 안방하고 거실 중에 어디에 로봇 청소기를 작동시키고 싶어?
# 집 바로 앞에서 트램타고 구시가지까지 한번에가는데 10분도 안걸려요!
# 덕분에 바로셀로나 곳곳을 하루종일 잘 다녔습니다.
# 총 27박 28일을 여기서 지냈는데요,
# 에어비앤비랑 트립닷컴이랑 비교했을 때 광고 메일이 더 많은 곳은?
# 땡볕엔 피부노출 금지야.
# 다중이용시설 중 중점관리시설은 이용 인원의 제한을 확대하고, 클럽에서의 춤추기, 노래연습장에서 음식 섭취 금지 등 위험도가 높은 활동을 금지한다.
# 효율이 더 나은게 선풍기였나요 에어컨이었나요?
# 학회 메일을 더 이상 그만 받고 스팸처리하고 싶은데 방법을 알려줘
# 언어 소통도 친절함도 모든것이 너무 좋았읍니다.
# 장점 포르투 여행하기에 위치가 정말 좋다.
# 세계 각국의 발표에서 가장 눈에 띄는 단어는 ‘신뢰’였다.
# 칠월 약속 리스트가 몇 개야?
# 저는 여기 숙소때문에 다시 뉴욕에 오고 싶을정도예요!
# 이런 어처구니 없는 일은 처음 당하죠.
# 샤워할때 좁은 공간에 샤워커텐이 몸에 달라붙어 짜증이 많이난다.
# 그 기차 타서 아토차역 한방에 갑니다!
# 지난 9월 세계경제포럼(WEF)의 관광경쟁력 평가 결과에서도 전 세계 140개국 중 16위로 역대 최고 순위를 달성했다.
# 알려줘. 손선풍기 판매하는 사이트.
# 위치 또한 매우 좋아서 이동에 매우 편리합니다.
# 그래서 의사소통할 때 조금 오래 걸릴 수 있습니다!
# 와이파이가 2층에서 좀 느리지만 사용할 만 합니다.
# 집밖은 보지말고 집안 습도 확인 부탁해
# 압류 부동산 매각을 보류하는 등 체납처분의 집행도 최장 1년까지 유예 조치하기로 했다.
# 용량이 더 큰 메일을 보낸게 거래처인가요 부장님인가요?
# 수입금액 100억~500억원(0.2→0.25%), 500억원 초과(0.03→0.06%)로 각각 높아진다.
# 게스트와 이뤄지는 확실한 커뮤니케이션과 문제점에 대한 케어는 호텔수준의 만족감을 느꼈습니다.
# 송도는 우리나라 최초로 ‘스마트시티’가 시작된 곳이며 끊임없는 실험과 진화가 거듭된 혁신 도시입니다.
# 두오모와 산타 노빌라역 등 모든 관광지와 가깝습니다
# 발코니쪽 창문은 3개중에 한개만 열수있습니다.
# 공수처와 같은 기관은 우리나라에만 있나요?
# 사장님과의 약속에 절대로 늦게 가지 말고 미리 가셔야 합니다.
# 특히 주방과 편안한 침실 또 한 완벽했습니다
# 약속을 바꿀 때에는 갑자기 말하지 말고 적어도 하루 전에 공지하세요.
# 계단이랑 문 앞에선 고양이 오줌 냄새가 약간 나요
# 약속장소가 어디로 바뀌었습니까?
# 저희에게 모든 부분에서 완벽했던 숙소였어요.
# 이들 사이트들은 한시적으로 5월 말까지 일반 학생들도 스마트폰으로 데이터 사용량에 대한 부담 없이 이용이 가능하도록 ‘제로레이팅(특정사이트 데이터 무과금)’으로 지원한다.
# 친절한 주인, 훌륭한 위치. 추천합니다
# 접근성, 숙소내 청결도, 편안함 좋았습니다
# 소품 하나 인테리어 하나 안 예쁜 게 없었습니다!
# 호스트는 친절하고 개인실은 편안합니다.
# 정 총리는 이날 정부서울청사에서 열린 ‘코로나19 대응 감염병 전문가 간담회’에서 이 같이 말했다.
# 인테리어와 주방시설 수납공간 모두 탁월했어요.
# 어디가 바뀐 약속장소지?
# 이달 28일부터 시행되는 자동차관리법 시행령 개정안은 무단 방치 차량의 강제처리 요건인 방치기간을 ‘2개월 이상’으로 특정했다.
# 덕분에 아주 싼 에스프레소 포터를 구입했어요.
# 그동안은 도난이나 횡령당한 경우에만 말소등록이 가능했다.
# 인원에 제한없이 가격이 동일하다는 것 때문에 가족여행 숙소에 적합했습니다.
# 우리나라는 작년에 몇 개의 태풍이 왔었나?
# 미세먼지가 높은 시기에는 운동을 금합니다.
# 바르셀에 또 방문한다면 무조건 이 집에서 머물거에요.
# 너는 오른쪽하고 왼쪽 중 어느 방향으로 에어컨 바람이 나오는게 나을 것 같아?
# 다만 개인 물품이 많아 약간 난감할수도 있긴 합니다.
# 거실하고 안방 불 켜져 있는지 확인해봐
# 어떤 원인으로 인해 연구실 메일 서버가 고장났을까?
# 그동안 여건상 예술인 450여 명이 대상이었지만 올해부터는 800명까지 확대한다.
# 침실에 누웠을 때 보이는 도루강 뷰는 정말 좋았어요.
# 태풍이 올까? 폭염이 올까?
# 처음 도착했을 때, 시내는 아니기 때문에 이동할 때 걱정이 될 수 있는데요.
# 이 가격에 번화가 숙소 구하기는 힘들테니까요.
# 열대야와 높은 습도 중 싫어하는 것은 어떤 것인가요?
# 숙소근처에 음식점 쇼핑몰 편의점 등이 있습니다.
# 우리는 세계적 대유행으로 인한 저소득 국가들의 채무취약성 위험을 지속적으로 다룰 것이다.
# 그런데 특이한 것은 한국 상황에 대한 보도 관점이 한국 국내 언론과는 전혀 다르다는 것이다.
# 특히 할아버지 너무너무 스윗하시고 친절하세요!
# 호스트도 매우 친절하고 무엇보다 방이 매우 깨끗해요.
# 먼저 데이터·인공지능(AI)분야에서는 데이터 활용을 높이기 위해 건강 등 민감한 정보에 대한 가이드라인을 8월까지 마련한다.
# 스트립이랑 도보 10분거리로 위치도 좋고 숙소도 깔끔합니다.
# 삼촌, 취침등이랑 독서등 중에 뭐 가질래요?
# 조용한 위치, 호스트의 배려, 좋은 벤쿠버의 날씨까지 완벽했던 여행이었습니다.
# 한번 잡은 약속은 어기지 말고 꼭 지켜라.
# 금융위원회와 금융권 등은 26일 열린 금융리스크 대응반 회의에서 코로나19 사태의 장기화를 고려, ‘취약 개인 채무자의 재기지원 강화방안’의 적용 시기를 연장하기로 했다.
# 위치는 정말 최고 주변에 마트 3개정도있고 시장이랑도가까워요.
# 위치, 청결, 주인과의 소통 모든게 좋았습니다.
# 내일 영화를 보기로 했나 모레 영화를 보기로 했나?
# 65세 이상 독거 노인 죽음, 전체 고독사의 43% 달해
# 이번 영상은 약 30초 분량으로 미국과 영국, 태국 주요 건물의 대형전광판 총 13개를 통해 상영된다.
# 부엌싱크 뒤쪽으로 샤워 부스와 화장실이 있습니다.
# 올해 코로나 방역 과정에서 우리가 얻은 것이 있다면 바로 그것입니다.
# 다만, 종교시설 등 4대 밀집시설에 대해 운영중단 강력권고를 해제하는 등 일부 제한은 완화한다.
# 집도 깔끔하고 호스트가 아주 친절해요.
# 버스노선을 잘 검색해가시는걸 추천할게요.
# 베란다에서 보이는 야경이 정말 멋있습니다.
# 옆방 게스트가 성별이 다른데 좀 신경쓰였어요
# 또한, 베이비부머 세대의 은퇴가 본격화되면서 2011년 40만명대에 불과했던 만 60세 도달인구는 앞으로 연간 90만명 이상으로 확대될 전망입니다.
# 정부는 이번 서울실증 외에도 도심항공교통을 위한 체계적인 실증사업, 버티포트(eVTOL 이착륙장) 기준 마련, 종사자 자격 연구 등을 추진 중에 있다.
# 겉에서 보는 것 보다 내부 공간이 훨씬 좋았어요.
# 다만 화장실에서 냄새가 좀 난다는 단점이 있다.
# 친절한 호스트, 낡은 건물이지만 양호한 객실 상태
# 일본에서 관리중인 도메인으로 메일을 보내는건 금지되어있습니다.
# 스차하이와 난뤄구샹이 걸어서 갈수있을정도로 가까워요.
# 문화체육관광부는 한국출판문화산업진흥원과 함께 5일 오후 2시 ‘코로나 시대의 인간과 기술’을 주제로 ‘인간과 기술 포럼’의 서막을 연다.
# 이번 회의에서는 1부에 코로나19 대응 지원대책에 대한 종합점검, 2부에 포스트 코로나를 준비하기 위한 정책토론으로 진행됐다.
# 다음에 또 마드리드에 갈 일이 생긴다면 반드시 이 곳에 다시 머물 생각입니다.
# 세탁 건조기 쓰지 말자 이번엔
# 위치, 주차, 침실, 아침식사 모두 너무 좋았고요
# 세비야의 전통적인 느낌이 있는 예쁜 집이었어요.
# 식기 세척기로 그릇 씻는 방법을 알려줘
# 쿠팡은 계속 차단해
# 시작 날짜 알려줘. 내장산 단풍.
# 세탁건조기 쓰지마
# 잠귀가 많이 밝은 분이면 조금 힘들것같긴합니다.
# 당신이 관광객이 아닌 여행자라면 주저없이 추천합니다.
# 여름말고 겨울에 난방 온도로 적정한 정도가 어떻게 되니?
# 예약한 숙소의 위치가 실제 숙소의 위치와 다를 수 있습니다
# 집은 2명이 머물기에 불편함이 없어요.
# 일본 동경 날씨 궁금합니다.
# 파리에서의 5박이 너무 뜻깊었던 순간이였습니다.
# 교수님은 메일로 연락드리는거 아니야
# 지역이 습해서 제습기 가동은 필수입니다.
# 24일 법무부에 따르면 체류기간이 곧 만료되는 등록외국인은 13만6000여명에 달한다.
# 숙소 주변은 주택가여서 조용한 편입니다.
# 계곡에 텐트치는 것은 비 올 때는 금지입니다.
# 중국에서 신종 코로나바이러스 감염자가 10만 명을 넘었다?
# 한편 상반기 중에는 소화전과 교차로, 버스정류장, 횡단보도 등 안전신문고를 활용한 불법 주·정차 주민신고 대상에 ‘어린이 보호구역’을 추가·시행할 방침이다.
# 방이 세개, 화장실 하나, 주방으로 이루어진 아파트를 나누어 쓰는 구조입니다.
# 전자레인지 한 달 사용 시간 알려줘
# 시설도 사진에서 보던 바와 같았습니다.
# 화장실, 부엌을 쓰는 데에 전혀 불편함이 없었습니다.
# 케이비에스랑 엠비씨 라디오 중에 어떤걸 네가 좋아하는지 알려줄래?
# 단풍으로 유명한 산이 어디지?
# 위치도 적절했고, 숙소도 엄청 깨끗합니다!
# 배송 주문 확인 메일 중에 쿠팡에서 온게 몇개야?
# 다만 방안의 침대는 두명이 자기에는 약간 좁았어요.
# 이와함께 부품 수입과 관련한 관세와 상반기분 부가가치세 납기를 최대 12개월 연장하고 최대 9개월 징수 유예를 지원한다.
# 모든 메일을 다운로드 받지는 마세요. 거래처에서 온 것만 받아주세요.
# 호스트가 알려준 저녁 식사 장소도 마음에 꼭 들었다.
# 이와 함께 150가구 미만 공동주택에서 소유자·세입자의 3분의 2 이상 동의를 받는 경우 의무관리대상 공동주택으로 전환할 수 있게 된다.
# 정부가 코로나19 긴급 대응에 ‘재해구호기금’과 ‘재난관리기금’을 적극 활용하도록 기금 사용 용도를 대폭 확대한다.
# 추진단은 문화예술교육 현장·학계의 외부 전문가 22명, 문체부 및 교육진흥원 담당자 8명 등 총 30명으로 구성된 민관협의체다.
# 위치는 우리가 자주가는 관광지에서 대부분 삼사십분정도 걸리는거리 같아요.
# 유럽여행동안 지냈던 숙소 중에 가장 친절한 호스트를 만났습니다.
# 병무청에 문의하려면 어느 메일 주소에 메일을 보내야할까요?
# 알려줘. 대관령과 진부령 중 겨울에 눈이 더 많이 오는 곳을.
# 개인적인 기준으로 화장실의 청결도는 약간의 개선이 필요해 보입니다.
# 중소·중견기업의 설비투자 촉진을 위해 정책금융기관 공동 ‘설비투자 붐업 프로그램’을 4조 5000억 원 규모, 최저금리 1.5%로 신설한다.
# 상사에게 메일을 보낼 때 표현이나 예절등을 어떻게 해야하지?
# 다음은 문 대통령 고용노동부·환경부·농림축산식품부 업무보고 모두발언 전문.
# 어떻게 빔프로젝터를 효율적으로 쓸 수 있어?
# 숙소근처에 마트가 있어 음식준비하기가 편합니다.
# 열대야 기준 온도는 몇 도인지 궁금합니다.
# 쪽방촌을 정비하면서 주민을 위한 공공임대와 민간 주택, 종합복지센터등으로 복합개발하는 ‘쪽방촌 순환형 개발’도 본격 추진한다.
# 코펜하겐에 다시 간다면 다시 이 집을 빌리기를 원합니다.
# 독특한 인테리어와 청결함이 인상적이었습니다.
# 테르미니역에서 길하나 건너면 바로 나옵니다.
# 아시아 마켓 큰 곳엔 한국 냉동 코너도 따로 있더라구요.
# 지난 2년간 공공임대주택, 금융·주거급여 등 맞춤 프로그램을 통해 200만 가구 이상의 주거안정을 지원
# 첫날 묵었던 타이베이의 4성급 호텔보다 훨씬 편하고 아늑합니다.
# 업체와 이번 주에 잡은 일정과 시간이 언제인가요?
# 방이 크고 주방에서 보는 동네 뷰는 환상적입니다.
# 너가 추천해줄 수 있는 가장 효과적인 거실 청소 방법은 뭐야?
# 그리고 사진보다 방이 훨씬 깨끗하며 상당히 큰 편입니다.
# 저는 다음 프라하 여정에도 이 곳에 머무를 생각이에요!
# 하지만 냉장고와 공용공간에 개인 물품이 많이 있습니다.
# 찬물 세탁할 때, 어떤 방법으로 세탁물 분류해야 돼?
# 올해 전 세계 21개국 25개 재외문화원에서 한국 대중음악(K-POP) 강좌를 진행했다.
# 너는 무드등하고 형광등 중 어느거 켜는게 더 좋을 것 같아?
# 다음날 공항에 가셔야 하는 분들께 강력 추천합니다.
# 이번달과 다음달 중에서 언제가 시험인지 알고 있습니까?
# 중앙시장 또는 가죽시장, 두오모 까지는 걸어서 조금 걸리더라고요
# 특히, 중앙정부-지자체 자본보조사업에 대한 실집행 관리 강화를 통해 지방투자를 확대한다.
# 자동차는 1년 만에 3개월 연속 증가와 올해 두 번째 높은 실적(39억 9000만 달러)을 달성했다.
# 흔히 우리가 접하는 태국음식이 아닌 고급스런 태국요리를 배울수 있었습니다.
# 또 생애 최초로 주택을 구입하는 신혼부부에 제공되는 전용 대출상품의 금리가 낮아진다.
# 야 거실 난방 이십오도로 설정할까, 삼십도로 설정할까?
# 한국 단체 가이드의 출발 지역과 매우 가깝습니다.
# 친절한 호스트, 깨끗한 방, 개인 화장실까지 불편함없이 뮌헨을 즐기다 갑니다.
# 태풍 오면 배 타면 안돼.
# 또 참여기관 확대에 맞춰 이용가능 계좌도 예·적금계좌 등을 추가한다.
# 소리에 민감하신 분과는 잘 맞지 않으실 것으로 봅니다.
# 창문을 통해 볼 수 있는 두오로강의 야경은 정말 감동적입니다.
# 리스본에서 제일 인기있는 알파마지구 한가운데에 있어요.
# 번역기의 도움으로 의사소통을 할수 있어요
# 이번주 스터디 일정은 어떻게 돼?
# 처음에 사무실 찾기가 조금 어려웠는데 전체적으로 좋았음
# 뉴욕여행을 계획하시는 모든분들께 강력하게 추천합니다.
# 호시우역과 엘리베이터 너무너무 가깝습니다
# 네이버에서 보관을 메일이랑 쪽지 중 뭘 더 오래하지?
# 현재는 추가로 특례허용을 진행, 6곳의 휴게소에서 공유주방이 운영 중이다.
# 이 외에도 안전신문고와 지자체 신고센터를 통한 ‘이탈자 주민신고제’를 운영, 민·관이 함께하는 다중의 모니터링을 실시할 방침이다.
# 약속은 취소하지 말아야 합니다.
# 메일이 몇 통까지 받은 메일함에 저장되는지 아세요?
# 특히 이번 신청은 2020년 구직지원프로그램(취업성공패키지, 청년구직활동지원금) 종료자, 진행 중인 자, 신규 참여자도 신청 가능하다.
# 아이를 위한 웰컴 장난감 선물과 모든 것에 대한 친절한 안내 등 다 좋았어요.
# 또한 요양병원 등에 대한 종사자 감염관리교육 예산과 대상을 확대하고, 감염관리 기본수칙별 표준교육 동영상 배포 등 방역 관련 교육도 강화한다.
# 건물 전체 또는 일부를 다 에어비앤비로 이용하더라구요.
# 지금 네가 보고 싶은 티비 프로그램 말해봐
# 누나, 가스렌지와 인덕션 중에 뭐로 요리하고 싶어?
# 베란다랑 거실 중에 어디가 불켜져있는지 너가 한번 확인해줄래?
# 숙소는 탁심광장에서 도보로 15분 거리에 위치하여 편리합니다.
# 다 지울까 안읽은 메일만 지울까?
# 새벽말고 낮에는 조명등을 좀 덜 밝게 하자
# 이러한 정책 여건을 반영, 방통위는 ‘활력있는 방송통신, 신뢰받는 미디어’를 비전으로 설정하고 3개 목표와 9개 과제를 올 한해 중점 추진한다.
# 호스트는 매우 친절하며 숙소 건물은 허름하나 내부는 깔끔한 편입니다.
# 이번에 세일하는 소파 꼭 사야 하니까 백화점 세일 일정 잊지 않도록 해라.
# 그리고 11월달 부터 보일러를 쓸 수 있다는 것 같았습니다.
# 적극적으로 소통하려고 하셨던 점도 매우 만족입니다.
# 대관령과 진부령 중 겨울에 눈이 많은 곳을 알려주십시오.
# 또 지난 1월 소부장 경쟁력위원회에서 핵심전략품목으로 선정한 100대 품목을 구현할 ‘100대 핵심전략기술’도 선정했다.
# 창가 방 주기적으로 삑삑 소리나는것은 해결되었는지 확인하세요.
# 다시 파리에 간다면 또 여기에 묵을거에요.
# 트립닷컴 예약을 했을 때 메일이 오는데 뭔 내용이 와?
# 식사를 거르면 몸에 살이 더 잘 찌게 되니까 거르면 안돼.
# 근데 유럽은 건식이니 물바다 조심하세요.
# 추가된 내일 세시 일정이 어떤 것입니까?
# 삼사월 두 달 중 메일이 많이 온 달을 알려줘
# 지하철 4호선 2번 출구 길 건너에 바로 있습니다!
# 여름철에 냉방 적정 온도가 몇도야?
# 저녁에 이중 약속을 잡으면 둘 다 안 가느니만도 못합니다.
# 네가 편하게 잘 수 있는 곳 중에 안방이랑 작은방이 어디가 좋니?
# 좀 멀긴 합니다만 사그라다파밀리아도 걸어갈 수 있는 거리긴 합니다.
# 비 올 때는 국수 대신에 부침개 먹는게 어때?
# 올해 황사 일수 알려주세요.
# 강풍 시에는 창문을 열지 말자.
# 여름철에는 상온에 음식을 오래 두지 않도록 합니다.
# 드라이기, 다리미, 냉장고 등 공용으로 사용할 수 있는 물품이 많았습니다.
# 그리고 정말 하루종일 잠만자는지 별로 사람 신경도 안씁니다.
# 그리고 이유는 모르겠는데 엘레베이터에서 이상한 냄새가 나요.
# 가족모임 일정이니까 까먹지 말고 우선순위를 일순위로 해주시길 바랍니다.
# 실업부조를 도입한 OECD 주요국가로는 독일, 프랑스, 영국, 스페인, 스웨덴, 핀란드 등이 있다.
# 마치 단독 주택에 사는 느낌이라고나 할까요.
# 로봇청소기 있잖아, 안방이랑 거실이 있는데 어디서 작동시키고 싶은거야?
# 음악 볼륨은 어떻게 조정하니?
# 아침에 안개가 낄지 맑을지 알려주게.
# 우리는 이 장소를 매우 사랑했기때문에 포르토에 3일을 더 머물렀습니다.
# 가격대비 위치 시설 청결 정말 완벽 했어요
# 카탈루냐 광장과도 지하철로 가까웠습니다.
# 복지부·여가부가 제공하는 육아나눔터, 다함께 돌봄센터, 방과후 아카데미 등의 돌봄 서비스도 이용할 수 있음
# 숙소 내부는 항상 깨끗하고 침구도 엄청 푹신푹신해요.
# 호스트의 세심한배려가 집 곳곳에서 느껴집니다
# 중기부는 수요기업이 바우처 이용시 선택 가능한 결제 수단을 현행 2종에서 4종으로 확대할 예정이다.
# 태풍 경로인 곳에 여행가면 안된다고.
# 비가 내릴 때는 우산 대신에 비옷을 사용합시다.
# 숙소의 규모나 편의시설에 비하면, 적절한 가격으로 판단됩니다.
# 사진보다 약간 집이 작은감이 있긴하지만 둘이 사용하기에 불편할정도는 아닙니다.
# 공항에서 찾아오기도 괜찮고 집에서 레드펀역 가는 것도 금방입니다.
# 이번 여행 에어비앤비 중에 가장 좋았어요!
# 무료주차장을 이용할수 있는 장점이 있습니다.
# 4명이 묵을 수 있는 충분히 넓은 공간과 안락한 침구가 좋습니다.
# 마당과 동물들이 예술임 자연친화적인 집 호스트님이 배려를 잘 해주심
# 제가 오늘 오후에 해야할 일이 무엇인지 알려주셔요.
# 조명을 좀 낭만적으로 꾸미고 싶은데 뭐가 필요할 거 같아?
# 야 이거 거실이랑 안방 중에 어디 켜고 싶은거야?
# 다만 집은 구시가지에서 조금 멀리 있습니다.
# 약속 시간은 늦지 말고 지켜.
# 내일 아침이랑 오후 중에 미용실에 언제 가실 계획이십니까?
# 전체적으로 상당히 관리가 잘 되는 숙소로 특히 침대가 정말 편했습니다.
# 게이오선 타고 신주쿠까지 20분 정도 걸립니다.
# 그리고 호스트분도 친절하고 답변도 빨리 와요.
# 또한 비대면과 관련된 법·제도도 지속 개선해나간다.
# 숙소의 크기나 청결도 면에서는 보통이지만 위치와 주차장이 최대 장점인 숙소입니다.
# 다음주에 자원봉사 언제 하기로 했어?
# 위치 근접성과 호스트와 커뮤니케이션도 편했습니다.
# 치안 매우 굿굿 마트 바로 집앞에 진짜 30초? 거리에 있어요
# 홍남기 부총리 겸 기획재정부 장관은 8일 4차 비상경제회의를 마친 뒤 정부서울청사에서 열린 관계부처 합동브리핑에서 ‘선결제·선구매 등을 통한 내수 보완 방안’을 발표했다.
# 성인 네명이 이용하기에 방4개와 독립된 침대 4개가 있어 편합니다
# 선생님, 가스렌지와 인덕션 중에서 뭐로 하고 싶으세요?
# 특히 혼자 여행하시는 분들에게 추천합니다
# 이번주에 치과를 가신다면 언제 갈 수 있으시죠?
# 한국에서 수천 킬로미터 떨어진 곳에서 친구를 얻을 수 있던 게 이번 여행의 가장 큰 행운이었습니다.
# ‘#고마워요_질병관리본부’ ‘#힘내요_질병관리본부’
# 위치도 테르미니역 근처라서 접근성이 뛰어납니다.
# 기존에는 신기술금융회사의 금융과 보험업 투자가 대부분 금지됐었다.
# 실물경제의 위축과 고용 충격은 앞으로가 더욱 걱정입니다.
# 쿠팡에서 온 배송 주문 확인 메일 개수가 어떻게 돼?
# 너는 지진과 해일 중 어느 것을 더 무서워해?
# 야 서재 조명등 이단계로 켜줄까, 삼단계 정도로 켜줄까?
# 밤에는 등산 하지 마세요.
# 7박8일간의 숙박 기간 동안 호스트는 총 세번 손님을 데려왔습니다.
# 다음 호스트와 연락을 하기 위해선 별도의 채팅앱이 필요합니다.
# 시설은 좋으나 잠자리 민감하신 분들은 다른 곳으로 가세요
# 네이버 쪽지를 최대 얼마나 되는 기간동안 저장할 수 있나요?
# 첫째 아파트의 분위기가 꽤 무섭습니다.
# 집은 가구랑 주방 기기 등이 다 고급이었습니다.
# 저희가 특히 좋았던 저은 세탁기, 건조기가 잘 완비되어 일어 매일 세탁할 수 있었던 점입니다.
# 대한항공 메일 중 중요한 메일이 있니?
# 29일 ‘문화가 있는 날’ 당일에는 전국 주요 영화관에서 오후 5시부터 9시 사이에 상영되는 영화를 5000원에 관람할 수 있다.
# 눈 올 때 썰매 말고 스키 타자.
# 저한테 전화거시는 빈도를 좀 줄여주세요.
# 그들은 매우 아름답고 멋진 친구들입니다.
# 주방에 각종 식기랑 향신료랑 커피, 차, 전자렌지 가스렌지 다있습니다.
# 다만 언덕을 오르내리기 힘드신 분들은 다소 걱정이 되는 부분이 있습니다
# 다음에 에딘버러 또 가면 여기로 올거예요.
# 3박 4일동안 불편한 점 없이 편안했어요.
# 열대야엔 술 마시지 맙시다.
# 논문발표날 늦으면 심사 탈락할 수도 있으니까 늦지 마.
# 파일 전송 지메일로 하지마
# 동기 모임이 잡혀 있는 주는 이번주야, 다음주야?
# 유일하게 딱 하나 단점은 와이파이가 없는것 입니다.
# 숙소 인근 로컬들을 구경하는 재미가 훨씬 좋았습니다.
# 방이 편안하고 사적 공간활용이 뛰어납니다.
# 무선 청소기가 청소하도록 조작하는 방법을 알려줘
# 효과 좋은 자외선 차단제는 뭐야?
# 이번 ‘남녀고용평등과 일·가정 양립 지원에 관한 법률’ 개정안에서는 육아휴직 분할사용을 확대했다.
# 제가 만약에 외출하고 싶을때가 있으면 방범 모드로는 어떻게 변환하면 될까요?
# 바로 앞에 슈퍼마켓과 다른가게들이 가까워서 여러가지로 편합니다.
# 스팸 메일함이 몇 통까지 스팸 메일을 담을 수 있나요?
# 도보로 7분정도 걸어가면 바로 아키하바라 입니다.
# 리스본에 처음 오시는 분들은 언덕 때문에 힘들 수도 있으나 이 지역에서 해당 숙소의 위치는 평균 이상입니다.
# 약속은 신뢰 문제니까 가급적 취소하지 말거라.
# 무튼 위치도, 숙소 청결도 및 숙소에 구비된 편의시설 및 여러 도구들이 너무 좋았어요!
# 또한 인증 기업은 항만시설 사용료 감면과 해양진흥공사 보증 한도 확대 세제 혜택 등 다양한 혜택도 받는다.
# 마지막으로 거울같은 중간문에 당황하지 말길 바란다.
# 수강신청한 것을 정정하려고 하는데 어느 기간에 하면 될까요?
# 단 세대주만 신청 가능하며, 세대주 명의 카드에만 포인트가 지급된다.
# 전체적인 인테리어나 디자인이 정말 앤틱하고 아름다워요.
# 다음 방문 때는 귀마개를 챙겨갈 예정입니다.
# 에어컨 바람은 직접 쐬면 안 된다.
# 또한 혁신성장 부문에 민간투자자금이 유입되도록 마중물 기능을 한다.
# 회의 안 잡은 요일 이번 주 중에 있으면 무슨 요일인지 말해주세요.
# 다른 메일은 확인을 하지 않으니 네이버 메일로 연락주세요.
# 이번 업무협약으로 추진하는 8곳의 도시생태축 복원사업 중 주요 사업을 보면, 경기 화성 건달산-기천저수지 생태축을 복원한다.
# 항만·해운분야에서도 선박 저속운항해역 지정·운영 및 외항선박 저유황유 사용 조기 전환을 시행했다.
# 위치, 청결상태, 친절함 정말 훌륭한 숙소였습니다.
# 머무는 4일동안 고양이 덕분에 행복했어요!
# 중기부가 이달 17일부터 공적 유통채널인 공영홈쇼핑을 통해 마스크 100만개 등의 판매에 나선다.
# 피렌체 중앙역 뒷편의 조용한 길에 자리한 널찍하고 편안한 아파트입니다.
# 너는 잠금장치가 중요하다고 생각해, 침입 경고장치가 중요하다고 생각해?
# 물론 식탁과 침대 사이 거리는 좁아요.
# 주인분이 쓰시는 물건이나 그림이 그대로 있어요.
# 개인별로 목욕물을 세팅하는 좋은 방법은 뭐야?
# 난방 온도를 이십오도 이상으로 설정할 필요는 없어
# 다음에 혹시 대만에 한번더 갈경우 또 이 숙소를 예약할것 같습니다
# 관광지가 가까운 곳을 원하고 파리나 런던 등에서 기차로 방문하는 분에게는 좋을듯 합니다.
# 저는 여자 셋이서 2주동안 묵었습니다.
# 저희 부모님께서도 정말 만족하셨습니다.
# 아버님께서 선호하시는 라디오 방송 채널이 뭔가요?
# 문화관광부는 지난해 관광객 역대 최대기록을 경신했죠?
# 결국 지금 우리가 직면한 지구환경적인 위기를 극복하기 위한 여러 가지 대안 가운데 하나로써 정부와 강원도가 수소경제에 주목하는 것에 대해 누구도 반대할 명분이 없는 것입니다.
# 주변에 24시간 슈퍼, 식당 그리고 가벼운 산책을 할수 있는 공원까지정말 완벽했어요
# 한라산에 눈이 오나요 그쳤나요? 지금.
# 불쾌지수 높을 때에는 긍정적으로 사고하세요. 나쁜 생각은 안됩니다.
# 티비 조정하고 싶을 때 할 수 있는 명령어가 뭐니?
# 지역사랑상품권 발행규모는 6조원으로 확대하기로 했다.
# 이밖에도 다양한 이벤트를 통해 참가자에게 선물이 제공된다.
# 약속을 미루면 여자친구가 두고두고 갈굴 테니 미루지 마.
# 청결도도 너무 좋아서 항상 깨끗한 상태의 화장실로 유지됩니다.
# 지메일 비밀번호는 자주 바꿀 필요가 없으니 그러지마
# 호스트와 연락이 잘 닿는 점이 좋습니다.
# 방도 한 사람이 머무르기 딱 알맞게 아늑합니다.
# 전국에서 파견된 250여 명의 공중보건의뿐 아니라
# 파리의 마지막 밤을 밸러리의 훌륭한 집에서 보낸 것을 행운으로 생각합니다
# 일정이 더 없는 주말이 이번주니 다음주니?
# 놀지 말고 집 앞을 치우는게 좋겠어. 눈 올 때.
# 추후에 샌프란시스코 공항에서 묵을일이 있다면 무조건 이용할 예정입니다.
# 일기예보 무시하지 마세요. 바다에서는.
# 코로나19 이후 경제 상황에 대비하기 위해 중소환경기업 지원사업이 대폭 확대된다.
# 이날 부동산시장 점검 관계장관회의에서는 이외에도 ▲공시가격 현실화 및 재산세 부담 완화방안 ▲부동산정책 후속조치 진행상황 및 계획도 논의됐다.
# 위치 까를교랑 도보10분 대형마트 도보5분정도에요
# 특히 이번에는 작가들이 네이버 오디오클립과 연계해 자신의 목소리를 녹음한 소리책(오디오북)을 제작한다.
# 대기업도 연수원 제공, 의료진 파견 등 힘 보태
# 아빠가 다음 달부터는 해외에 계시니 가족모임 일정 바꾸지 말거라.
# 선정된 모든 학교에는 동복, 하복(또는 생활복) 디자인 개발과 시제품제작을 지원했다.
# 집에서 직접 요리 해먹어
# 알려줘. 내일 불쾌지수가 육십보다 높을지 낮을지.
# 수강생 메일에는 하트 표시 말고 별표를 해주세요.
# 산림청이 식목일을 앞두고 ‘2020 내나무 갖기 캠페인’의 일환으로 ‘아주 특별한 나무 배달부’ 이벤트를 진행한다.
# 빔프로젝터와 대형 티피 중에 너는 뭘 살 것 같아?
# 호텔 수준의 깨끗한 침구와 개인실 느낌의 욕실이 좋았어요.
# 집도 너무 청결하고, 침대도 푹신합니다.
# 냉장고에 생수가 없었던점과 드라이기가 없는점이 아쉽습니다.
# 테라스에는 해변의자 몇개 뿐 아무것도 없었어요.
# 그리고 방음이 잘 안되서 저녁에 소리지르는 사람들의 목소리가 그대로 전달됩니다.
# 너무 큰 용량의 메일은 저장하지마
# 이메일 보안을 주로 다루는 회사들로는 어떤 회사가 있나요?
# 방 구성이 심플하고 위치는 매우 좋아요.
# 지난 2월 이후 실직, 무급휴직, 일감상실 등으로 소득 감소를 겪은 이들이 대상이다.
# 3. 이번에 승인한 제품 외 다른 제품을 추가적으로 승인할 계획은 있나요?
# 복도에 있는 화장실은 게스트 용으로 저희만 사용 했어요.
# 한 학기동안 본 호스텔에서 지냈습니다.
# 저번 년도에 제일 큰 태풍의 이름을 알려주십시오.
# 이에 따라 정부는 내년까지 개방 가능한 데이터는 모두 개방한다.
# 허나 엘리베이터가없음을주의하시길바랍니다
# 지진 시에 건물 엘리베이터는 이용하지 말자.
# 놀라운 사실은, 구글 번역기가 많이 유용하단 것이었구요!
# 다만 건물안에서 휴대폰이 잘 안터졌어요!
# 메일함에 모든 메일을 남겨두기 보다는 거래처에서 온 메일은 다운로드하는 것을 부탁합니다.
# 지금 에어컨 희망온도 어떻게 설정되어있어?
# 올해는 사업 참여 대상자를 중소기업 및 소상공인 근로자뿐만 아니라 사회복지법인, 비영리민간단체 근로자까지 확대한다.
# 도보 가능한 거리에 관광지, 음식점, 마트가 있어 편리합니다.
# 이날 목요대화는 KTV 생방송과 총리실 페이스북, KTV유튜브로 생방송될 예정이다.
# 이 로봇청소기 있잖아요 안방이랑 거실 중에 어디서 작동하고 싶니?
# 어떤가요? 대전 미세먼지 예보는.
# 위치나 방의 청결도는 매우 만족스러웠습니다.
# 가족단위 또한 직접 음식을 만들어 먹을 사람에겐 다소 불편한 위치입니다.
# 유리 테이블도 실제로는 상당히 컸습니다.
# 전반적으로 괜찮은 편이나  칼 및 프라이팬 등 식기가 좀 부족한 편이며 일부 수건이나 침구에서 냄새가 좀 나내요.
# 그리고 강아지와 고양이를 키우니 동물을 안좋아하는 사람들은 비추입니다.
# 참, 건물 외관에서 볼 때는 좀 실망하실 수 있어요.
# 두 가족들이 함께 보낸 좋은 시간이었다.
# 지급받은 카드를 잃어버렸어요.
# 세탁기 사용을 어떻게 예약하는 건지 알려줘
# 국내 최대 SF 과학축제 ‘SF2020’이 6일 개막해 15일까지 열린다.
# 아마 전에 머물었던 사람들이 두고간 물건같아요!
# 소방관들은 올해에만 73만 곳의 구조출동 현장에서 7만 명의 국민을 지켰습니다.
# 잊지 말고 마스크 쓰렴. 미세먼지 높을 때는.
# 별 하나 뺀거는 조리기구가 너무 부족했어요.
# 혹시 약속 시간 하루 전에 변경할 때에는 늦지 말고 사유를 얘기해주라.
# 내년에 과기부 기초연구사업 신규과제 공모내용과 추진일정은 과기부, 한국연구재단 홈페이지에서 확인할 수 있다.
# 다음 달 여행 언제 가?
# 여태까지 한 에어비엔비 중 최고의 방이었던 것 같네요.
# 알려줘. 유럽과 아프리카 중 올해 여름에 더운 곳.
# 처음 방키찾는것에 약간 혼선이 있었지만요.
# 대문말고 현관문 잠금장치 점검해야 되니까 업체 불러.
# 그래도 전반적으로 마음에 드는 숙소였습니다.
# 에어컨 풍향 조정하고 싶으면 뭐라고 해야 되지
# 나하고 볼 수 있는 시간이 오늘 언제인지 알려주겠나?
# 이를 위한 금융서비스로 민관합동으로 800억원 규모의 펀드를 결성해 50% 이상을 공공기술을 사업화하는 창업기업 및 기술기반 기업에 투자한다.
# 주말에 가려고 한 계곡 어디에 있는지요?
# 특히 주방에 냄비, 후라이팬, 헹주등 상태가 넘 안좋습니다.
# 그게 제가 다시 여기 머물고 싶은 가장 큰 이유입니다.
# 여러분이 좋다고 생각하는 목욕물 온도는 몇도인가요?
# 근처에 히가시주조역, 주조역이 있어서 오가기 편합니다.
# 남자친구 생일이 몇 월 며칠이야?
# 정부의 RD 투자와 승인 절차 단축 등이 뒷받침되어야 코로나19 치료제와 백신 개발에 더욱 속도를 낼 수 있을 것입니다.
# 특히 정부는 향후 일부 기업에서 검토 중인 해외현장 내 방역상황 점검·자문 등을 위한 국내 민간의료진 파견을 적극 지원할 계획이다.
# 너 카카오톡 로그인에 사용중인 메일 주소가 뭐야?
# 울산 동구 주전어촌체험휴양마을은 성게미역국과 전복요리를 맛볼 수 있는 곳이다.
# 해변도 30분 이내로 다 도착할 수 있어요.
# 국민 안전을 최우선으로 두면서 신속한 임상 승인 절차를 도입할 예정입니다.
# 숙소도 매우깨끗하고 인테리어도 예뻐요!
# 내일부터 시행하는 해외 입국자 2주간 의무격리 조치가 잘 지켜지는 것이 중요합니다.
# 편한 체크인, 깨끗한 집안 상태 좋아요
# 각국 정상들의 통화요청도 쇄도 중이다.
# 좋은 장소에서 행복한 시간을 보냈습니다.
# 와디즈 광고 메일은 받지 않도록 설정해줘
# 선생님, 거실이랑 안방 중에 어디에 조명이 들어왔으면 하는거에요?
# 영어를 잘 구사하시는 것은 아니지만 체크인 시, 여행 중, 체크아웃까지 항상 친절하세요.
# 아들이 인턴쉽 하러가는게 언제래?
# 약속이 언제 있지, 내일 아니면 모레?
# 침대류도 거의 새거와 같은 상태였습니다.
# 매일밤 술 취한 사람들의 소리와 길 가는 사람들의 대화가 다 들리는 숙소였다.
# 그 외, 역실문이라던지 현관문도 덜렁거려 보수가 필요할 것으로 보인다.
# 숙소 위치와 환경 청결도 진짜 좋아요.
# 불쾌지수가 높은 곳이 대구와 홍천 중 어디야?
# 조금 특이하게도 집이 길쭉한 형태고요,
# 트위치 계정은 메일 주소가 몇개까지 등록이 가능하니?
# 지금 한라산에 눈이 와? 아니면 그쳤어?
# 학교로부터 나한테 온 메일이랑 회사에서 온 거 중 뭐가 더 많아?
# 하지만 전철역에서 가깝고 야시장 가기는 편해요.
# 또한 마을회관과 경로당 등 주민 공용시설 300곳을 지원 대상으로 선정했다.
# 저번에 효율이 좋다고 했던게 에어컨이었나요 선풍기였나요?
# 멈추지말고 세탁 계속 해
# 또 지각하지 말고 대학후배 결혼식장에 일찍 가자.
# 어머님이 원하시는게 독서등이신가요 아님 취침등이신가요?
# 야 선풍기 바람 회전하게해줄까, 고정하게 해줄까?
# 세비야 관광지, 식당, 교통편응 지도로 자세히 설명해줍니다.
# 위치, 편리성, 청결도, 집크기, 편의시설 모두 좋아요.
# 처음 체크인 할 때 만 조금 주의하면 나머지는 아주 편합니다.
# 이 행사는 과학기술정보통신부가 주최하고 대한무역투자진흥공사와 정보통신산업진흥원이 주관한다.
# 책 읽는데 형광등 키는 건 좀 아닌거 같으니 그만해
# 앞으로 두 번 이상 신고되는 아동학대 사례가 발생시에는 피해 아동을 학대 행위자로부터 적극적으로 분리 보호하게 된다.
# 지금과 같은 전대미문의 위기 속에서 ‘협치’는 더욱 절실합니다.
# 저희 가족이 지내기 알맞은 규모에 깔끔한 인테리어와 청결도에 모두 만족하였습니다
# 다음에 또 베를린을 간다면 역시 번잡한 시내보다는 조용한 이곳을 선택할 것입니다!
# 아쉬운점은 침대와 침구류가 좀 아쉬웠네요.
# 영화를 보기로 한 약속이 내일이야 모레야?
# 세심한 배려와 정성에 너무 감동하였습니다.
# 1인당 1주일에 타올이 1개 지급이라고 합니다!
# 공시가격별 세율 인하 효과 사례(분석 전제 : 현실화 계획에 따라 매년 현실화율 제고, 시세 변동은 없음)
# 프라하 웬만한 관광지 다니기 좋은 위치에 있어요.
# 형광등말고 백열등 사용하자
# 좀 더 체계적이고 , 호텔같은 서비스를 제공합니다.
# 안방에서 조명등 키지마
# 오늘 부모님이랑 언제 저녁 먹지?
# 아예 늦가을이나 겨울엔 문제 없을 것 같습니다!
# 특히, 고양이 2마리가 정말 귀여웠어요.
# 부엌에서 요리할수 있도록 식기구가 충분해요 !
# 시간이 다 돼서 준비하지 말고 교수님 미팅 자료는 미리 준비합시다.
# 아 고양이를 키우시는데 고양이 있는 지도 모를 정도로 얌전해요.
# 주말에 가기로 예정했던 계곡이 어디에 위치하여 있는지 알고 싶어요.
# 서울시 은평구는 14일 코로나19 확진자를 대상으로 진행한 심층역학 조사 결과를 발표했다.
# 국민의 목소리, 민원을 넘어 정책으로
# 지난 2005년 노무현 전 대통령이 친환경 수소경제 구현을 위한 마스터플랜을 수립한 이후 14년여 만이다.
# 세탁기 멈추는 건 금지되어있어
# 태풍 경로가 한국과 일본 중 어디일지 찾아주십시오.
# 국내외 출판 전문가들을 위한 온라인 저작권 상담과 강연, 해외 출판관계자들을 대상으로 한국 책을 분야별로 소개하는 영상을 볼 수 있다.
# 이 숙소에 머물며 아쉬운 점은 우리가 하루밖에 이용할 수 없었다는 점입니다.
# 공항까지 최소 90분 이상 걸리기 때문에 짧은 일정일 경우 별로입니다
# 알려줄래? 황사가 올지 비가 올지.
# 다음 주에 비 오는 날은?
# 세비야 대성당은 걸어서 1분도 안걸리는 위치예요!
# 주거비 부담 경감을 통한 소비 여력 확충안도 담겼다.
# 일단 숙소의 감각적인 인테리어가 마음에 들었어요.
# 형, 이번 달 가스 사용료 낼 때 돈 얼마나 냈어?
# 다른 호스트중엔 체크인부터 아웃까지 코빼기도 안보이는 분도 있는데 이분은 맞이부터 배웅까지 확실합니다.
# 엄마 식기 세척기를 사드릴까요, 식기 건조기를 사드릴까요?
# 공용공간으로 주방과 화장실 모두 크고 쾌적합니다.
# 교수님 미팅에 늦으면 교수님의 신뢰를 잃을 테니 제시간에 와.
# 단 한기지  단점은  옆방  소음이  들리는 것입니다.
# 에어비앤비 사이트에서 보는 사진이랑 똑같아요.
# 깨끗한 침실과 넉넉히 구비된 수건, 과일과 와인까지 제공합니다
# 인테리어가 예쁘고, 침대 시트, 소파, 수건이 모두 깨끗합니다.
# 지금 이 시간에 재밌는게 네가 좋아할만한게 뭐 있을까
# 둘째, 추경은 끝이 아니라 시작입니다.
# 제주 지역은 얼마나 비가 왔나요? 지난 주말엔.
# 쿠팡에서 오는 메일은 계속 받지 않도록 한 설정을 해제 하지마
# 슬플 땐 참지 말고 빗속을 달려보세요.
# 호스트님의 빠른 소통이 굉장히 인상 깊었습니다.
# 쿠팡 광고메일은 답장하지 말고 삭제해
# 재해피해가 제일 큰 태풍은 무엇이었습니까? 한국 역사 중에서.
# 올해 단풍은 어디에서 처음 핍니까? 도시 기준으로.
# 아울러 데이터 활용에 따른 개인정보 처리자의 책임을 강화했다.
# 일단 첫번째 숙소 위치가 너무 좋습니다
# 실내용 슬리퍼가 없는건 살짝 아쉬웠습니다!
# 엘니뇨 현상의 가장 큰 원인은 뭐야?
# 반층 내려간 침실은 아주 넓은 침대 2개와 욕실이 있습니다.
# 내일 저녁에 영화 예약한 거 몇 시야?
# 혼자 뉴욕 여행하시는 분이라면 강추합니다!
# 내일 동아리 모임 시간이 언제라고 했었니?
# 가장 높은 강도인 3단계는 전국적으로 하루 800-1000명 이상 확진자가 나오거나 더블링(일일 확진자 수가 2배 이상 증가) 현상이 발생할 때 발령된다.
# 한류 문화의 우수성을 또 한 번 세계에 보여준 쾌거입니다.
# 다만 욕실의 수압이 좀 많이 약하다는 것이 아쉬웠습니다.
# 지메일 비밀번호는 자주 바꾸지마
# 저는 머무는 10일의 시간이 정말 즐거웠습니다.
# 그래도 버스를 이용하면 좋을 거리예요.
# 폭우가 있을 때에는 홍수 말고 산사태를 주의하기를 권합니다.
# 드럼 세탁기랑 통돌이 세탁기 세척력 비교해봐
# 이탈리아에 체류하는 우리 국민과 그 가족들은 탑승 전 건강상태질문서를 확인해 유증상자를 분류한 후 좌석을 분리한다.
# 이번 협의회는 창업·벤처기업의 역동성이 살아 숨쉬는 현장인 판교 제2테크노밸리에서 진행한다.
# 햇빛이 심할 때는 떙볕에 피부를 노출하지 맙시다.
# 깨끗하고 호스트의 배려가 돋보이는 숙소입니다.
# 아침엔 차가운 물말고  더운 물 샤워를 하는 게 좋겠어.
# 에어비앤비 광고메일이 더 많아, 트립 닷컴 메일이 더 많아?
# 사실 이게 에어비앤비를 이용하는 가장 큰 이유기도 하고요
# 집안 조명등 밝기 상태는 뭘 해야 알 수 있어?
# 거듭 거듭 강조하지만 무엇보다 중요한 것은 속도입니다.
# 신주쿠쪽으로 자주 여행가실분에게 추천할만한 숙소입니다
# 주차장을 갖추고 있는것은 매우큰 장점입니다.
# 이번 달하고 다음 달 중에 시간이 언제 날 거 같아?
# 뉴욕과 함께 저지시티의 매력을 함께 느낄 수 있는 최고의 장소라고 생각합니다.
# 장마 전에 놀지 말고 하수구 청소하자.
# 국내 체류기간 연장을 위한 공공기관 방문을 최소화해 감염병 확산을 적극적으로 차단할 필요가 있다는 판단에서다.
# 근데 뜨거운 물 너무 많이 쓰면 끊기는 것 같긴 해요.
# 퇴실이 12시라는것도 아주 큰 장점인듯해요
# 군더더기 잡을 것 없는 좋은 방이었습니다.
# 주변에 편의시설도 가깝기 때문에 런던 도시 여행자에게 추천합니다
# 많을지 적을지 확인해줄래? 구름의 양을.
# 키패드로 운영되는 곳이라서 편리합니다.
# 가성비굿 무거운 짐들고 올라가긴 좀 빡셈
# 보낸 메일함에서 메일에 별표를 하고 싶은데 어떻게 하는거야?
# 단풍이 올해 처음 피는 도시는 어디입니까?
# 잘때 팝송말고 클래식곡 들어보지 그래?
# 3박4일동안 즐거운 여행할수 있었습니다
# 기관마다 차이가 있지만 통상 ‘상담→서류신청→현장실사→보증심사→보증서 발급→은행 대출’ 절차를 거친다.
# 출생년도 끝자리별로 조회·신청 가능한 요일은 월요일 1·6, 화요일 2·7, 수요일 3·8, 목요일 4·9, 금요일 5·0, 토요일 홀수, 일요일 짝수로 정해 접수한다.
# 일본의 국가 메일 코드가 어떻게 되지?
# 호스트가 집을 잘 관리하는 편이라 생각합니다.
# 다른 게스트가 사용했던 오래된 파스타면이 그대로 있었고요.
# 비 내릴 땐 잊지 말고 높은 지대에 텐트 치세요.
# 주변이 씨끄럽거나 메인거리는 아니지만 힙한 청년들이 많은곳인듯 합니다.
# 30분안에 청소가 얼마나 깨끗하게 될까요?
# 어제와 그제 중에서 언제 일일 일식을 하셨는지요?
# 사육시설의 규모가 1000㎡ 이하이고 방역실 내부에 별도의 물품반입 장소를 갖춘 경우에는 설치 예외 대상이 된다.
# 티비 어떤 명령어로 조정하는 지 좀 알려줄래?
# 요리할 때 인덕션말고 가스레인지로 쓰자
# 앞으로 보름 동안 우리는 새로운 일상을 침착하게 준비할 것입니다.
# 인덕션 사용하면 큰일나
# 열대야와 높은 습도 중 싫어하는 것을 골라줘.
# 숙소가 정말 청결하고 집 컨디션이 최고예요.
# 눈 내릴 땐 등산 하지마세요.
# 소액 수의계약 한도를 두배 상향하고, 입찰공고 기간을 단축하는 한편 입찰·계약보증금도 절반으로 낮춘다.
# 역이랑 좀멀지만 가성비굿 은근 소음거슬림
# 토플 스터디 모임 예정 시간이 언제야?
# 모니터말고 스피커는 블루투스 기능이 있는 걸로 구매하자.
# 그리고 고양이가 정말 애교가 많답니다 !
# 다만 겨울에추위 많이 타시는 분은 추울수 있어요!
# 게다가 아파트에 커피머신이 있어서 훌륭합니다.
# 숙소는 아주 쾌적해서 가족 여행에도 적합합니다.
# 표정과 제스쳐로 따듯한 마음을 알 수 있었습니다.
# 금요일엔 따로 부탁드릴 일이 있으니 약속일정 잡지 말아 주세요.
# 교수님 뵙기로 약속한 시간이 언제이신가요?
# 당신과 당신가족의 건강과 번영을 위해 기도할게요.
# 빈의 분위기를 느끼기 좋은 공간이었습니다.
# 사랑하는 가족을 잃은 유가족과 동료의 죽음을 가슴에 품고 계신 소방관들께 깊은 위로의 마음을 전합니다.
# 말 없이 늦지 말고 지각하기 전에 미리 말해.
# 지하철역 바로 앞에 위치하고 호스트도 친절합니다.
# 호스트에게 매우 감사하고 이 숙소를 추천합니다.
# 좀 도쿄 외곽이라 관광지랑 먼게 아닐까?
# 공지 메일이랑 설문 메일 중 뭐가 수신거부 상태지?
# 이가격에 절대 이런숙소에묵을수없을것같아요!
# 여자분 혼자 지낼 숙소로는 비추천하고 호스트가 없는 시기에 이 집을 빌리는건 더더욱 비추천해요.
# 로마에 다시 온다면 이 숙소를 다시 선택할 거에요.
# 내일 황사 지수는 어떻습니까?
# 가격도 스톡 중심가에서 이만한 집이 없어요.
# 올해도 지난해에 이어 공무원이 적극적으로 일할 수 있고 국민이 생활에서 체감할 수 있는 적극행정을 추진한다.
# 내일 오전 수업 시작이 몇 시야?
# 늦게 낸 레포트는 안 받으니 알아서들 처신하세요.
# 해당기관은 중소기업제품 구매 촉진 및 판로지원에 관한 법률 제2조제2호에 따른 공공기관으로, 총 구매액의 1000분의 3이었던 현행 비율을 1000분의 6으로 높였다.
# 지메일의 첨부파일 개수는 최대 몇개인지 알 수 있나요?
# 집 뒤에 바로 홀리루드 파크와 궁전이 있습니다
# 혹시 가족행사는 이번주와 다음주 중에 언제 있으신지요?
# 최적의 위치, 깨끗한 실내 그리고 도쿄의 물가를 생각하면 정말 합리적인 가격을 가진 멋진 숙소입니다.
# 식중독 말고 감기를 조심해야지. 겨울철에는.
# 진짜 이가격에 이숙소면 다음에도 또 갈만한 곳이다.
# 할아버지가 알려준 츄러스 진짜 맛있었어요.
# 한편, 유료방송을 통한 EBS 온라인 강의는 각 급 학교의 정상등교 전까지 한시적으로 운영될 예정으로 유료방송 별 채널번호는 EBS 홈페이지에서도 확인할 수 있다.
# 오늘 나를 만날 수 있는 시간이 언제야?
# 지메일을 통해 제 인스타그램 비밀번호를 받을 수 있는 방법을 알려주세요.
# 심지어 공항 픽업 서비스까지 제공해주세요
# 정부는 중장기 개발 기간이 필요한 소부장 특성을 고려해 협력·축적 중심의 연구 생태계 활성화 기반을 마련한다.
# 방위사업청은 1974년 이후 45년 만에 방산원가 구조를 전면 개선했다.
# 신경 못 쓸것 같은 선반 같은곳도 깨끗했어요
# 하지만 28인치 캐리어 두 개 펼쳐놓을 공간은 있는 정도?
# 지하에 있는 카렌이나 4층에 있는 훠궈집이요!
# 제 경험 중에서 가장 친절하고 정확한 숙소입니다.
# 정부 기관에는 지메일 말고 네이버 계정으로 메일을 보내야 합니다.
# 형광등을 리모트 콘트롤하려면 어떻게 해야 돼?
# 센트럴 런던 중심가에 위치한 데다 교통까지 편리하여 여행, 비즈니스에 최적화된 위치입니다.
# 특히 욕실의 라디에이터 덕분에 빨래도 엄청 잘 마르고요.
# 그리고 숙소는 사진 보다 실제로 보는 것이 훨씬 멋지다.
# 특히 근처 젤라또 집이 무척 맛있었어요 !
# 2015년 메르스 때 30% 인하했던 것 보다 2배 이상으로 확대한 것이다.
# 한두분이 지내기에 좋은 숙소라고 생각해요.
# 숙소 도착하기까지 그야말로 알 수 없던 숙소였어요.
# 내일 알바 언제 가세요?
# 호스트가 친절하지만 게스트 편의에 대한 안내보다 집 보안유지에 대한 설명에 신경쓰는 느낌입니다.
# 위치,청결,시설,호스트 모두모두 완벽해요
# 어떤 방식으로 학회 메일을 스팸 메일에 추가할 수 있어?
# 이번에 오는 태풍의 규모는 어떻습니까?
# 2인 이내의 여행자에게 자신있게 추천합니다.
# 이어  ‘특정 분야의 투자집중으로 인한 투자 감소’(40.0%), ‘특정 분야에 대한 정부 지원 집중’(38.8%) 등도 우려하는 요인으로 나타났다.
# 친구하고 설날에 약속 잡으면 가족들이 서운해 하니 약속 잡지 마.
# 자네가 켜고 싶은게 티비인가 라디오인가?
# 에어컨 키면 큰일나
# 오늘 국무회의는 확대 중대본 회의를 겸해서 개최합니다.
# 내 카카오톡 계정을 회사 메일로 쓰는지, 학교메일로 쓰는지 알려줘
# 보일러 얘기하는 게 아니고 도시가스는 많이 쓰지 않는게 좋을 거 같아
# 계단때문에 짐을 옮기기 힘든것 외에 만족했어요.
# 와디즈 주소로 오는 광고 메일은 차단해
# 거리도 공항과 주요관광지와 가까웠습니다.
# 근처에 초등학교가 있는지, 아이들 떠드는 소리가 재법 들립니다.
# 미래 신소재에 대한 부처 간 이어달리기 트랙을 추가로 신설하고 출연연 사업을 중심으로 과제가 아닌 주제 중심의장기연구 및 기술축적을 위한 오래달리기 프로그램도 추진한다.
# 다시 묶어서 다시 후기를 작성하긴해요.
# 북한이랑 중국 중 메일 발송을 할 수 없는 곳이 어디에요?
# 커다란 창문으로 이스탄불의 풍경을 볼 수 있어요.
# 또한 조건불리지역 수산직불금 지원 대상지역을 고성 등 접경지역까지 확대하고, 수산정책자금 지원규모도 확대한다.
# 떠나는 날에 아주머니를 만났는데 그분은 영어를 잘 하십니다.
# 무엇보다도 집주인의 친절함에 감동받았습니다.
# 숙소 사진과 굉장히 싱크로율이 높아요.
# 다음에 하와이에 방문하면 또 묵을 예정입니다.
# 생각보다 방이 조금 습한 느낌이 있었다.
# 특히 유로스타 타고 다른곳으로 넘어가시는 분에게는 최상의 위치 입니다.
# 증조할머니 제사 날짜가 언젠가요?
# 한가지 아쉬운점은 방음이 조금 부족 하지만 시설과 위치 가격 내부물품 모두  훌륭함
# 앞서 경기도는 도민 모두에게, 서울시는 중위소득 100%이하 가구에 긴급재난소득을 지급했다.
# 피해가 계속될 경우 지자체가 직접 철거에 나설 수 있다.
# 아침에 산책 계획이 있는거니, 오후에 있는거니?
# 에어컨 바람을 직접 쐬는 건 금지되어있어
# 환경부와 중소벤처기업부는 3일 ‘그린뉴딜 유망기업 100’ 출범식에서 이같은 내용을 포함한 ‘그린 스타트업·벤처 육성 방안’을 발표했다.
# 세탁기랑 티비 전원 보여줘
# 그녀 아파트 아래에서 바로 자전거도 빌릴 수 있어요
# 포항 지진의 규모 알려주세요.
# 집에서 보이는 자연 경관이 아주 근사하다.
# 물론 최근의 파리 교통 상황 영향이 클 것 같습니다.
# 한국어 학회 시작 날짜가 어떻게 되죠?
# 저기요, 이거 거실이랑 안방 중에 있잖아요 조명 어디에 불 들어오게 하고 싶으신거에요?
# 올해 국가공무원 5급 공채는 행정직군 249명(지역구분모집 28명 포함)과 기술직군 71명(지역구분모집 10명 포함), 외교관후보자 50명 등 370명을 뽑는다.
# 기업 당 최대 지원금도 기존 2억 원에서 3억 3000만 원으로 상향됐다.
# 하지만 3박을 지내는동안 개인당 수건1장, 휴지 1롤만 제공되는건 아쉽네요.
# 처음 예약할 때 일부러 숙소를 바티칸 근처로 잡았는데요,
# 국내 스타트업들은 코로나19 이후 유망 산업분야 1순위로 진단키트, 마스크, 원력의료 등 의료분야를 꼽았다.
# 해질녘 풍경부터 아침햇살 가득 내려앉은 풍경, 그 속에서 따뜻한 호스트와 귀여운 캥거루들의 모습을 잊을 수가 없네요.
# 너희 부모님 집 가스레인지 한달 비용이 얼마이니?
# 비슷한 가격에 호텔 가실거면 여기를 추천드려요.
# 오후에 여가시간 있으면 뭐 하는게 좋아?
# 메일을 보내기 전엔 제목 말고 내용을 두 번 체크하세요.
# 어떤 도메인을 사용할 때 학교 메일로부터 거부당하나요?
# 무엇보다 품격있는 인테리어와 조용함, 동네의 안전도 마음에 들었어요.
# 저희는 한명은 밤에 한명은 아침에 씻었어요.
# 프로페셔널한 숙소 관리, 저렴한 가격, 나무랄데가 하나도 없어요.
# 시설도 깔끔하고, 호스트도 매우 친절합니다.
# 바로 길 건너 레스토랑도 너무 맛있었고요.
# 논문 발표하기로 한 게 몇 월 며칠이에요?
# 다만 집에서 아쉬운부분은 문소리가 크다는것과 욕실이었어요
# 한국 사람이 이 방을 쓴 게 처음인 것 같네요!
# 밥 일인분 취사 레시피를 알려줄래?
# 에어컨한테 음성명령 내리는 방법 좀 알려줘
# 한편으로 국민의 눈높이에 맞는 병영문화를 정착시켜야 합니다.
# 전반적으로 샌프란시스코에서 좋은 경험이었다.
# 몇 월 며칠에 내장산 단풍이 시작하는지 압니까?
# 메일을 굳이 다 다운로드 하는 것 보다 거래처에서 온 것만 모두 받는 것이 어때?
# 메일은 다 지울수도 있고, 안읽은거만 지울 수도 있어. 어떻게 할래?
# 벽에 장식된 그림들과 조명등이 인상적이었어요.
# 주변에 편의점이나 식당들도 많아 좋을거에요.
# 덥다고 찬 음식 그렇게 많이 드시면 안되세요.
# 약속장소는 고민하지 말고 분명하게 공지해주십시오.
# 토요일 밤부터 일요일까지는 대부분의 마켓, 상점들이 문을 닫아요.
# 메일 쓰는거랑 손편지 써서 군대 밖으로 보내는 거 둘 중에 뭐가 더 쉬워요?
# 넓은침대와 넓은집 그리고 호스트가 너무친절합니다
# 메일에 답변을 해주시는 비율이 교수님이랑 조교님 중 누가 더 높지?
# 미세먼지 지수가 높을 때는 운동은 하면 안됩니다.
# 거래처 사람들과 만날 때 지각하지 말고 제시간에 도착하도록 하게.
# 뉴스 방송하는 채널 번호를 알려줘
# 다음주 며칠에 출국해?
# 번개칠 때 우산 쓰지마.
# 또한 분야별 기업군의 경쟁력을 높이기 위해 다수 기업이 공통으로 필요로 하는 특허 분석을 바탕으로 한 기업군 공통 IP-RD 추진도 병행한다.
# 사진으로 보는것보다 훨신더 실제가 너무 좋아요 .
# 아파트 상태는 사진보다 더 좋았습니다.
# 주요 일정들이 언제쯤 겹치죠?
# 위치, 호스트, 청결 모든게 기대 이상이예요!
# 로마를 다시 간다면 꼭 다시 갈 것입니다.
# 집은 놀라울 정도로 청결하고 거의 매일 침실을 정리합니다.
# 저녁에는 도로에 차다니는 소리외에는 아무 소리도 없이 조용했습니다.
# 17개 중점기술에는 5G 통신, 인공지능(AI)·데이터, 사물인터넷(IoT), 실감형 콘텐츠, 스마트공장, 스마트시티 등이 있다.
# 식기 세척기 이번달 전기 사용료가 얼마야?
# 그리고 숙소근처에 있는 마트에서 알찬 쇼핑도 할 수 있었다.
# 따라서 ‘생활방역 지침’에는 일상생활이나 경제활동과 조화를 이룰 수 있는 개인·환경 위생관리 수칙과 사회적 거리두기 핵심 수칙을 담을 계획이다.
# 다음주에 잡힌 저녁 약속이 총 몇 건인지요?
# 지난 2018년 취업자 증가는 9만 7000명에 그쳤습니다.
# 규모가 더 큰 것은 토네이도인가요? 아니면 허리케인인가요?
# 이날 바이오업계는 바이오 전문인력 공급을 위한 시설 건립, 새로운 시장 창출을 위한 규제완화, 세제 등 인센티브 확대 등을 정부에 건의했다.
# 유럽여행 내내 그 어느 곳 보다 좋은 숙소였어요
# 논문발표날은 절대 늦으면 안돼.
# 그 점 외에는 많은 면에서 만족스러웠습니다.
# 냉장고 문 열려고 시도하지마
# 특히 세면대는 따뜻한 물이 쫄쫄 나와서 세수하기 힘듭니다.
# 방컨디션은 사진과 똑같이 깔끔했습니다.
# 숙소는 사진보다는 약간 좁은 느낌은 있어요.
# 나폴리 가장 번화한 거리에 안전하고 깨끗한 숙소입니다.
# 대신 머무르던 둘째날 부터 와이파이에 접근할 수 없었던 점은 아쉬웠습니다.
# 위치,청결,호스트의 친절 등등 모든게 완벽했다.
# 사진이랑 같은 멋진 공간에서 7일 머물렀어요
# 엘니뇨 때 다른 것 말고 폭우에 주의합시다.
# 그래서 저는 더욱 만족스러운 여행을 한것 같아요
# 마스크의 4가지 원재료는 스펀본드 부직포·MB필터·이어밴드·노즈클립이다.
# 무엇보다 트리쉬가 정말 잘 케어 해줍니다.
# 이만한 가격에 훌륭한 컨디션과 위치입니다
# 내가 학교에 보낸 메일이랑 거래처에 보낸 메일이랑 더 많이 보낸 곳 알려줘
# 일월하고 이월 중 일정이 많으신 때를 알려주세요.
# 보낸메일함이랑 임시보관함 중에 뭐가 더 메일을 오래 보관하지?
# 큰도로 바로 앞이라 자동차 소음이 그대로 들린다.
# 아침마다 울리는 세비야 대성당 종소리도 조금 힘들긴 했지만 아주 추천하는 숙소입니다!
# 다음에 볼로냐를 또 온다면 다시 예약할 것입니다.
# 상반기 중으로 낙동강 유역의 상수원 문제 해결 대책을 확정하고, 영산강·섬진강의 물 수요·공급, 수자원 현황 등을 종합적으로 고려한 통합 물관리 방안 마련도 추진한다.
# 공중보건의사는 농어촌 등 보건의료 취약지의 보건(지)소에서 진료업무 등을 담당하는 의사로서, 원칙적으로는 4주간의 군사교육을 받고 2일간의 중앙직무교육 후 시·도에 배치한다.
# 비가 내릴 때에는 방심하지 마세요. 안전운전 하십시오.
# 체크인 시간과 체크아웃 시간이 아주 자유로워요.
# 단한가지 한국인들은 샤워기 사용이 조금 복잡한데 물나오는 수도꼭지 부분을 아래로 잡아당기세요.
# 텀블벅 광고메일은 수신거부하기보단 허용하는 것이 좋아.
# 아침식사인 토스트와 잼도 굉장히 맛이 좋았다.
# 한인가족이 운영하는 숙박으로 2인 1실이긴 하지만 가격대비 굉장히 만족합니다.
# 수건에서 쾌쾌한 냄새가 난 것과 집 문을 열기 어려웠던점, 그리고 침대가 불편했습니다
# 각종 질병의 예방관리 대책을 수립·추진하고, 감염병에 대응하는 질병관리본부(이하 질본)를 응원하는 메시지다.
# 호스트와 헤어지기 전에 문을 여는 것을 꼭 테스트 해 보시길 바랍니다.
# SPV 출범은 3차 추가경정예산(추경)이 국회를 통과한 후 이뤄질 예정이다.
# 황사 올 때는 외출을 자제해주십시오.
# 에스아이셀, 피플웍스는 전기차 배터리를 재활용하여, 전기자전거, 전동킥보드 제조업체에 공급합니다.
# 지금까지 온 모든 메일 말고 삼월에 온 메일만 영구보존함으로 이동시켜
# 다만 화장실이 매우 좁은편이었던건 불편했습니다.
# 여름에 갈 만한 카페를 든다면 어디인가요?
# 메일 보낼 때는 다른 계정 말고 네이버 계정으로 보내줘.
# 매우 친절한 부부 내외 덕분에 숙소 생활은 즐거웠습니다.
# 부기보드,비치의자,비치우산,쿨러 까지 다 갖춘 숙소입니다
# 독서는 ‘아이’, ‘엄마’, ‘독서모임’, ‘책스타그램’, ‘전자책’, ‘소리책(오디오북)’ 등이 핵심 연관어였다.
# 고양이가 귀엽고 호스트분이 다정하세요!
# 앞선 분기 성장률에서는 1분기(-1.3%)·2분기(-3.2%) 연속 마이너스 성장을 했다.
# 엘레베이터가 없다는 점은 꼭 참고하시길바래요
# 통상적인 시장에서 정상적인 거래가 이루어지는 경우 성립될 가능성이 가장 높다고 인정되는 가격 (부동산공시법 제2조).
# 마드리드에 와서 제일 잘한 것은 이 숙소를 선택했다는 점입니다.
# 따뜻한 마음으로 친절히 대해주신점 정말 감사합니다.
# 아울러 각 지자체는 친환경농산물을 원활히 공급받을 수 있도록 생산자단체 또는 광역단위 산지유통조직, 친환경농산물 취급자 등 유통업체 등과 공급계약을 체결한다.
# 상한 음식 먹는거 금지야.
# 하지만 문제는 숙소 난방이 안됐습니다.
# 손으로 하지 말고 세탁기로 시작해주세요
# 유투브 영상을 지메일을 통해 같이 보고 싶은데 어떻게 해?
# 세탁기,냉장고 모두 구비되어 있기때문에 마치 내집에 있는것 같이 편안합니다.
# 아 근데 나흘 중 마지막 밤에 물건 강매하는 삐끼를 두번 마주치긴 했어요.
# 잘 구비된 주방에서는 현지인처럼 근처 마트에서 장을 봐서 요리를 하기에 아주 적합합니다.
# 또한 여름철 체온상승에 따른 불편함 해소 및 임무수행여건 보장을 위해 기능성 원단을 적용한 컴뱃셔츠를 신규 보급한다.
# 런던 중심부 근처에서 묵기에는 가격대비 정말 좋다고 생각합니다.
# 둘이 쓰기에 아주 충분하고, 화장실도 깨끗합니다.
# WP는 바이러스와의 싸움에서 한국이 가진 가장 효과적인 무기로 ‘빠른 진단검사 확대’를 꼽았다.
# 다음 스페인 여행때 또  갈수있었음  좋겠어요
# 할머니 생신잔치에 늦으면 불효니까 늦지 말도록 해라.
# 이렇게 되면 아파트 등 공동주택은 연 3~4%, 단독주택은 3~7%씩 공시가격이 오른다.
# 위치도 시설도 호스트분도 부족함 없이 완벽했습니다.
# 뜨거운 물도 바로바로 잘 나오고, 필요한 모든 시설이 제공되는 좋은 숙소입니다.
# 주택가에 있어서 밤에 굉장히 조용합니다.
# 우리 모두 낭비하지 말고 에어컨을 절약합시다
# 공동공간에서 같이 얘기하는 분위기도 좋았습니다.
# 모레 바람이 약할지 강할지 현재 예측이 가능한가요?
# 부엌도 거의 마음대로 쓸 수 있었어요.
# 알려주십시오. 포항 지진의 규모를.
# 엘리베이터 에스컬레이터 등 모두 너무 편리하고요.
# 중대사고 시 재발 방지 대책 승인 전 공사 진행을 불허하고, 사고가 잦은 민간 건축공사 부실감리는 퇴출한다.
# 그 주요 내용만 간단히 말씀드리겠습니다.
# 체크인 과정은 아주 순조로웠고, 시설 또한 매우 깨끗합니다.
# 정부청사 구내식당들은 좌석배치를 변경했다.
# 그리고 애옹이들도 너무 귀엽고 주인분들도 친절갑입니다,,
# 티비 프로그램 중에 시사다큐 말고, 예능은 꼭 보자
# 집안 조명등 밝기 상태 알아보는 방법이 뭐야?
# 교수님께 드릴 말씀이 있을 때 메일로 하면 안돼
# 사장님과 한 약속에는 지각하지 말고 미리 가라.
# 시장 가서 어떤 물건을 사 오시게요?
# 울릉공항은 총사업비 6651억이 투입돼 50인승 소형 항공기 전용으로 건설된다.
# 어디로 약속장소가 바뀌었나?
# 몇 명이나 열대야 고수부지에서 외출하나요?
# 다만 흡연 가능 아파트이기 때문에 방 복도까지는 약한 담배 냄새가 날 수 있다는 점만 주의하시면 돼요!
# 국토부는 고령가구에 대해서는 2025년까지 무장애 설계가 적용된 공공임대 8만호를 공급한다.
# 판테온에서 1분 거리에 있는 숙소로 위치 정말 좋습니다.
# 주변은 아랍 및 동양계가 많이 사는 것 같습니다.
# 갑자기 약속을 변경하지 마시고 적어도 하루 전에 미리 알려주십시오.
# 자꾸 클래식곡 틀려고 하지마
# 굉장히 깨끗한 숙소이고 호스트 또한 매우 친절합니다.
# 주인장이 직접 디자인한 욕조도 멋졌구요.
# 알고싶어. 어린이 장화의 가격.
# 최근 스팸메일이 온 시간을 알려줘
# 운동 그냥 그만두고 싶으면 운동 스케쥴 미뤄.
# 호스텔에서 관리하는 호스텔 맞은편 에어비앤비인거 같아요
# 결제 메일 내용 좀 알려줘
# 남자친구가 언제 태어났는지 알아?
# 이 숙소에 머무신다면 만족에 만족하실겁니다.
# 우리만 쓸 수 있는 화장실이 좋았습니다!
# 텝스 스터디 모임이 매주 몇 차례 있죠?
# 가습기 사용하는 방법을 알려줄래?
# 연구실 메일 서버 상태를 진단하고 회복시킬 수 있는 서비스를 알려줘
# 가성비를 따지는 여행객, 친구랑 같이 온 여행객, 침사추이에 잠깐 묵고 갈 사람들에게는 추천합니다.
# 정말 위치,숙소의 상태 전부 좋습니다!
# 최근 글로벌 경제는 미국, 중국, 유럽연합(EU)이 1분기 마이너스 성장을 하는 등 코로나19의 충격이 가시화됐다.
# 베개는 좀 높았지만 전체적으로 만족합니다!
# 한국의 산업구조와 사회는 화석연료 의존도가 높은 편이기 때문에 탄소중립의 실현은 쉬운 일이 아니다.
# 친구가 결혼한 날이 언제인지 알고 있니?
# 메스트레와 가까워서 공항, 본섬 가기 좋은 위치입니다.
# 자원봉사 다음주에 어느 때에 한대?
# 중국에서 지메일을 어떻게 사용할 수 있나요?
# 드라마말고 네가 생각하는 시간 떼우기용 오락프로그램으로 알려줘요
# 화장실을 제외한 방 문에 잠금장치 없어요.
# 따뜻하고 무엇보다 호스트의 배려가 돋보입니다
# 프리푸드에 있는 메모 또한 기억에 남습니다.
# 안 읽은 메일함을 어떤 방법으로 읽음 처리할까?
# 효과 좋은 자외선 차단제를 알고싶습니다.
# 하하 주인이랑 연락은 잘 되는 편이에요!
# 또한 2020년 연도 내에 이미 건강검진을 받은 1년 주기 검진 대상자는 2021년 건강검진 수검이 가능하다.
# 손님 전기 스토브를 켜드릴까요, 보일러를 켜드릴까요?
# 이번주에 중간고사가 있습니까 다음주에 중간고사가 있습니까?
# 어떤 학회가 홍보 메일을 보내니?
# 세탁기, 건조대, 헤어드라이기, 다리미, 청소기조리도구, 간단한 조미료와 간식 등등 까지 모두 완벽한 숙소였습니다.
# 테이블 위, 문 손잡이, 욕실기구, 키보드, 침대 옆 테이블 등 손길이 많이 닿는 곳의 표면은 자주 닦아야 한다.
# 다음주에 언제 출국하는지 일정이 궁금해요.
# ‘데이터 가공인력’, ‘디지털 강사’, ‘인공지능 개발자’ 같은 직접적인 일자리는 물론 파생되는 새로운 일자리를 많이 창출할 수 있게 될 것입니다.
# 길이 막혀서 대학후배 결혼식장에 지각하기 보다는 일찍 가도록 하자.
# 세율 인하 폭은 공시가격 현실화에 따른 세 부담 완화 취지와 지방재정에 미치는 영향을 종합적으로 감안하여 결정
# 시가 9억원을 초과하는 주택의 전세대출 보증도 제한하고 차주가 전세대출을 받은 뒤 2주택 이상 보유할 경우 전세대출이 회수된다.
# 무엇보다 가장 좋았던 것은 매일매일 집에서 나올때 바로 가까이서 스카이트리를 볼수 있다는 것이었습니다
# 안개 낄 때는 그냥 가지 말고 비상등 켜주세요.
# 또 현실화율이 현저히 낮은 부동산의 공시가격 급등에 따른 부담을 고려, 연도별 제고 상한은 평균 제고분의 2배인 6%포인트로 적용하기로 했다.
# 지난해 제정된 어선안전조업법이 올해부터 시행되면서 어선에 대한 안전관리가 대폭 강화된다.
# 열대야는 몇 도가 기준 입니까?
# 남해 꽃 피는 날짜 언젠지 알려줘.
# 아웃룩에 외부 연동을 할 때 네개 이상은 지양해
# 지메일로 제 인스타그램 암호를 받도록 하려면 뭘 해야하나요?
# 그리고 나아진 후에도 계속 안부를 물었어요
# 위치는 렌트를 한다면 아주 추천합니다!
# 무엇보다 주인 아주머니께서 엄청 친절하시고 한깔끔 하십니다!
# 날씨가 어떤가요? 일본 동경은.
# 지금 야외 말고 집 안 습도 확인 좀
# 제사 시간은 까먹지 말고 미리 가서 도와주시길 바랍니다.
# 한달에 한 번 에어컨말고 냉장고 청소 안하면 큰일 나
# 피사의 사탑에 다녀오느리 피렌체를 더 돌아볼 시간이 부족했던게 아쉬울만큼 많은 정보를 주었습니다.
# 버스로도 쉽게 찾아갈 수 있는 거리입니다.
# 휴지통도 휴지넣는 곳도 전부 녹슬었다.
# 라니냐와 엘니뇨 중 무엇이 생길 예정인가요? 내년에는.
# 회식이 아마 늦게 끝날 것 같으니 회사 회식 뒤에 일정은 잡지 마.
# 티비 조정하고 싶을 때 쓸 수 있는 명령어 뭐가 있어
# 학회 홍보 메일이 어디서 오니?
# 제가 연동해서 카카오톡이랑 사용중인 메일이 학교거에요, 회사거에요?
# 지금 안방이랑 거실 어디 불 켜져있어
# 곳곳에 비치된 물품에서 호스트 분의 배려가 돋보였어요.
# 로마에서 최고의 위치를 가진 숙소인 것 같아요.
# 어디에서 발생합니까? 태풍은.
# 아니면 환승을 여러 번 하는 수 밖에는 없습니다.
# 숙소가는 길에 맨날맨날 에펠탑 볼 수 있어요.
# 먼저, 산업·발전 부문에서 대기오염총량제를 확대 시행하는 한편, 30% 강화된 배출기준 적용과 질소산화물 배출부과금 부과 등을 통해 다량배출사업장 배출량을 20% 이상 감축한다.
# 다음주 출국 일정이 며칠로 예정돼 있습니까?
# 다만 엘레베이터 없는 층고높은 5층건물에 짐을 들고 올라가실때는 단단히 마음의 준비가 필요합니다.
# 프라하 여행에 있어 완벽한 위치에 있는 숙소 입니다.
# 가정집에서 난방 틀때 효율적인 방법은 뭐야?
# 처음 체크인 할 때에 집안이나 수건에서 냄새가 약간 느껴집니다
# 아파트에 난방은 안 되는 것 같습니다.
# 선생님, 좋아하는 클래식 곡 중에 알려주고 싶은거 있나요?
# 메일을 저장할 때 용량을 확인하고 너무 크면 저장하지마
# 방심하지 말고 구조물 주의하기. 태풍으로 강풍 불 때.
# 언제가 부모님 결혼기념일이시죠?
# 그냥 호텔 보다는 훨씬 좋은 경험이라고 생각한다.
# 자외선이 강할 때는 일반 화장품 말고 선크림 바르세요.
# 저 개인의 다짐이 아니라 우리 국민 모두의 염원을 이루기 위한 정부의 목표와 의지를 말씀드린 것입니다.
# 지금 거실 조명이 켜져있는지 어떻게 확인할 수 있어?
# 저녁 약속 이번주에 몇 개야?
# 학교 메일은 수신거부 안할래
# 요청 사항에 빠른 답변과 조치가 있었습니다.
# 운동하러 가려면 아침이 좋아, 저녁이 좋아?
# 세비야 광장과 세비야 대성당은 20분 내외로 닿을 수 있습니다.
# 전자레인지와 커피메이커, 커피포트가 있어서 간단한 조리도 가능합니다.
# 일정에 늦기 보다는 미리 늦는 사유를 연락해주시길 바랍니다.
# 대전 미세먼지 예보 알려줘.
# 군인 친구한테 메일을 보낼 땐 이상한 내용을 보내지마
# 몇 월 며칠 입니까? 올해 장마가 끝나는 날짜는.
# 우선, 이날부터 1339 상담인력을 27명(기존 상담인력 19명, 질병관리본부 역학조사관 등 파견 8명)에서 19명을 새로 투입해 40여 명으로 배치한다.
# 총 2조원 이상 규모의 자발적 민간투자와 글로벌 기업의 국내투자도 구체화됐다.
# 사람 대하는걸 원체 좋아하는 친구입니다,
# 다만 집에 들어갈 때 문을 3개나 거쳐야 되기 때문에 처음에 찾을 때는 다소 불편합니다.
# 전체적으로 가격대비  만족스러운 숙소였습니다.
# 관광이 목적인 경우에도 집의 위치가 매우 나쁘진 않을 것입니다.
# 테라스에서 와인한잔 하기도 좋고 분위기도 매우 낭만적입니다.
# 고비 사막과 아프리카 중 건조한 곳은?
# 주방 스토브나 세탁기 돌리면 전기가 계속 내려갑니다.
# 혼자 오시면 도미토리보다 이곳을 추천해요!
# 동기들끼리 회사 회식 끝나고 커피나 한잔 할까 하니까 뒤에 일정 비워둬.
# 더운물로 목욕하는 건 좀 자제해
# 음악 볼륨 좀 조정하고 싶은데 뭐라고 명령어를 말해야할 지 모르겠네
# 아사쿠사나 스카이트리근처의 숙소를 원하시면 추천드려요.
# 네이버는 최대 몇 개까지 메일 계정을 만들 수 있나요?
# 비 올 때 우산 없이 나가지마.
# 식당이나 편의시설이 가까이에 있어서 편리 합니다.
# 하지만 나머지는 정말 완벽한 숙소였어요!
# 학교 아니고 집이니까 조명을 최소로 해두고 나가렴
# 작년엔 며칠이 가장 긴 열대야였어?
# 선풍기 풍향 조정하려면 뭐라고 명령해야해?
# 이 과정에서 ‘한-메콩 협력기금’과 공적개발원조도 계속 늘려갈 것입니다.
# 무엇보다 역과 매우 가깝기 때문에 좋았습니다!
# 다른 메일 말고 학회에 답변 보낼 때는 교수님을 참조에 넣도록 해.
# 여행이 다음 달 언제로 예정되어 있는지 알고 싶어요.
# 그린뉴딜은 기후 위기 및 환경문제에 대응하는 ‘그린’과 국가 주도의 대규모 경기 부양 정책인 ‘뉴딜’의 합성어로 경제와 산업 시스템의 대전환을 의미하는 개혁정책이다.
# 그렇지만 안락한 이 집 때문에 무사히 파리여행을 끝냈습니다.
# 이와 관련 공직 내 차별적 인사요소를 개선하고자 임기제공무원의 잔여임기에 따른 육아휴직 제한이 폐지된다.
# 그리고 엘리베이터와 전자키인 점이 상당히 만족스러웠습니다.
# 집 바로 앞에 콜로세움이 보이는게 큰 장점인 것 같아요.
# 같은 기간 강남 4구도 15억원 초과는 0.40%→0.11%, 9억원 이하는 0.36%→0.24%로 줄었다.
# 첫 에어비앤비 2일 잘 보내고 갑니다.
# 거의 모든 것을 갖추고 있는 가성비 좋은 숙소입니다.
# 또 전매제한 규정을 위반한 경우 10년간 청약을 받을 수 없도록 입주자 자격이 제한된다.
# 바르셀로나 가시는 분들 꼭 시내에 묵을 필요 없으시면 이 숙소 추천드려요!
# 스타트업과 벤처기업의 코로나19 위기 극복을 지원하기 위해 마련된 이번 특례보증은 4000억원 규모다.
# 습도기 보지마
# 어떤 이유로 넌 메일을 만들게 되었니?
# 올해와 내년 중 공휴일이 언제 더 많은지 알고 계십니까?
# 가격대비 굉장히 넓은 방에서 지내다갑니다.
# 벚꽃 축제 중 서울 여의도에 하는 것은 시간이 언제입니까?
# 이를 위해 국토부는 스마트시티형 규제특례가 적용되는 ‘스마트규제혁신지구’를 신설한다.
# 그 라디오 방송 프로그램 말예요 이름이 뭘까요?
# 사진과 설명에 나와있는 그대로 입니다.
# 집 바로 앞이 핀초로 유명한 거리인 것도 좋더군요.
# 아마도 피렌체 숙소가 더 좋았기 때문에 상대적으로 비교 되었을 수도 있습니다.
# 보통 도보 15분정도로 관광지를 다 둘러볼 수 있었어요.
# 실외 습도는 어떻게 찾아볼 수 있어?
# 미세먼지 농도가 높을지 낮을지 확인해주십시오.
# 겨울철에 온수 히타 사용도 아주 만족스러웠습니다
# 하지만 방이 추웠고, 지하라 사람들 계단오르내리는소리가 들립니다.
# 조금 많이 먹은 날은 쇼핑거리에서 천천히 걸어올만 했습니다.
# 가습기 아니고 에어컨과 선풍기는 같이 쓰도록 해
# 학교 메일 수신 비율과 광고 메일 수신 비율 중 뭐가 더 큰가요?
# 600년된 건물이라 잘때 살짝 무서운기분이 들기도 합니다.
# 무급휴직 지원 요건을 완화하고 타격이 심한 항공지상조, 면세점업 등은 특별 고용 지원 업종으로 추가 지정한다.
# 상한 음식은 먹으면 안돼.
# 결제 메일은 정크 메일함으로 가지 않도록 설정해줘
# 집 문을 열었을때 좋은 향기가 나는 유럽 에어비앤비는 처음이였어요.
# 우리는 주차장에 접근 할 수있었습니다.
# 접근성, 위치, 시설 등 전반적으로 매우 만족스러웠어요!
# 작은 런던의 가정집을 느낄 수 있어요.
# 친구를 어느 요일에 만나는지 알려주시겠습니까?
# 까다로운 우리 엄마도 매우 만족하였네요.
# 다음에 또 묵고 싶은 에어비앤비입니다!
# 올해 상반기까지 지방재정의 60%인 137조원을 조기에 집행하고 지자체에서 확보한 예비비나 재난관리기금도 위기 극복에 적극 활용한다.
# 세탁기로 씻길 땐 잊지말고 세제 꼭 넣어
# 이 집에서 지내는 동안 피렌체를 편안한 마음으로 관광할 수 있었습니다.
# 신청은 24일부터 대한병원협회에서 받고, 준비가 되는 병원부터 즉시 적용한다.
# 단, 2층 손님들이 시끄러운 경우 거의 그대로 들리는점은 단점인거 같습니다.
# 야 새벽 아니고 낮이니까 조명등 밝기 좀 낮춰서 쓰자
# 전남해안 장마 시작일 알려줘.
# 저 에어컨 온도는 이십오도 밑으로 내려가면 안되게 해줘
# 선생님, 심리적 안정감을 원한다면 조명 밝기가 어떤게 좋을까요?
# 소나기는 언제 옵니까? 강원영서 지역에.
# 하수구에 음식 버리지마.
# 아파트에 도착하기까지 언덕을 걱정하지마세요.
# 뮤지컬 시간이 내일 몇 시입니까?
# 숙소는 더할 나위 없이 너무너무 좋았습니다
# 카카오톡 연동기능 이용시 회사 메일을 사용하면 안돼
# 그만큼 어지간한 명소는 다 걸어갈 수 있어요.
# 내일 수강 신청에는 놓치지 말고 미리 대기하도록 하세요.
# 아동학대피해아동에 대한 응급조치 기준 개정 사항.
# 정확한 위치, 친절한 호스팅, 완벽한 공간 그 모든게 어우러진 최고의 장소였습니다.
# 이들 상품은 네이버, 카카오, 티몬 등에서 진행되는 크리스마스마켓 라이브커머스 특별 판매전을 통해 최대 50% 할인된 가격으로 판매된다.
# 대학 후배 결혼식에 가는 거면 늦지 마셔야 합니다.
# 영하의 추운 날씨엔 얇게 입고 나가지마.
# 저희가 머무는 동안 따뜻한 물은 잘 나왔습니다.
# 산타노벨라역에서 가깝고 베키오다리랑도 가까워요.
# 정부가 코로나19 사태로 어려움을 겪는 중소기업과 소상공인들의 비부동산 담보 활용을 통한 자금 조달을 활성화하고 골목상권 상점가 업종 요건을 완화한다.
# 문 하나를 기준으로 양쪽에 각각 집이 있고, 그 중 하나를 사용하는 거에요.
# 아내분이 종일 청소를 하셔서 쓰는 게 미안할 정도.
# 에어컨 작동 예약 언제로 설정해놨어?
# 주변 공기가 아주 신선하고 생쾌합니다.
# 자전거 타던 그 순간이 저랑 남자친구 둘 다 최고의 좋았던 순간으로 뽑았습니다.
# 학회 메일에 답변할 때는 다른 사람 말고 교수님을 참조에 넣어.
# 이에 운영 차량이 300대 이상인 경우 기여금을 100% 납부해야 한다.
# 첨부파일 전송시 네이버 메일은 얼마정도의 속도가 나오나요?
# 정부 대표 국민참여플랫폼 ‘광화문1번가’가 모바일 앱으로 출시, 앞으로 스마트폰 등에서도 소통이 가능해진다.
# 드레스덴가는 버스터미널 플로렌츠도 지하철 10분 정도요.
# 저번처럼 지각을 하지 말고 알람은 여러개 설정하게나.
# 주방 빨래 샤워실 침실 모든게 완벽했습니다.
# 주방 물은 잘안내려가고 네명이 자기에는 조금 불편합니다.
# 활동 계획을 겨울에는 실외 말고 실내로 잡으세요.
# 또한 시내와 다르게 늦은 시간에도 안전합니다.
# 다만 단점은 경사가 급한 계단이 뭐 보통 이동때는 괜찮지만요.
# 학생 평가는 원격수업에서 학습한 내용을 근거로 등교 이후 지필평가를 하는 것을 원칙으로 하기로 했다.
# 단점을 꼽자면 엘베가 없다는 점 정도?
# 안방에 있는 불 끄지 말아줘
# 레포트를 늦게 제출하면 받지 않을 겁니다.
# 냉장고 안에 있는 내용물 볼 수 있는 방법 좀 알려주세요
# 현지인처럼 아파트에서 지낼수 있는 좋은 기회였습니다.
# 다만 역에서 숙소까지 조금 거리가 있으니 참고하세요
# 위치, 청결 상태, 주변 편의시설 모든게 좋았어요.
# 호스트 대신에 청소부가 저를 맞이했습니다.
# 작년 2020학년도 수능에서 부정행위로 적발된 253명의 수험생 중 4교시 탐구영역 응시방법 위반자가 106명(약 42%)으로 가장 많았다.
# ‘인공지능 반도체 산업 발전전략’의 차질 없는 이행 및 성과점검을 위해 정부와 산·학·연이 참여하는 ‘인공지능 반도체 산업 전략회의’를 구성·운영한다.
# 공수처 검사와 수사관은 어떻게 뽑나요?
# 전세계 10개국이 모여 디지털정부 협력 방안을 논의한다.
# 봄이나 가을 같은 계절에 다시 오고 싶은 곳입니다.
# 법·제도적으로는 지자체가 직접 다양한 주체들 간의 소통과 협력을 지원하는 지역문화협력위원회를 설치·운영할 수 있도록 ‘지역문화진흥법’을 개정한다.
# 제 생에 최고의 여행을 이 집과 이웃분들과 함께 했습니다.
# 사장님 약속에 딱 맞춰 도착하기 보다는 미리 가는게 좋겠다.
# 보일러 점검은 구월말고 시월 종료 전에 마칠 수 있게 협조 바랍니다.
# 광고 메일 중 가장 큰 부분을 차지하고 있는 토픽은?
# 과학기술정보통신부는 6일 ICT 규제 샌드박스 지정기업의 올해 3분기 주요 성과를 발표했다.
# 블루투스 스피커 설치하려면 어떻게 해야돼?
# 찜통 속에서 요리하기를 원한다면 추천한다.
# 주말 약속 시간은 오전보다는 오후로 해야 한단다.
# 언제가 한국어 학회 시작일인지 좀 알려주시겠습니까?
# 우리 국민과 그 배우자 및 직계가족 중국인 170여 명 내외를 이송하는 이 임시항공편에는 중국 측의 출국 검역을 통과한 사람들이 탑승하게 된다.
# 날짜를 계속 변경하기보다는 한번 정한 약속날짜는 그대로 진행합시다.
# 포르투갈에서 오래 머무르실 거라면 평타 이상입니다.
# 당월 전기요금 청구서에서 요금의 50%를 차감하는 식이다.
# 많은 인원도 문제 없을 정도의 넉넉한 공간이였습니다
# 이 숙소의 알파이자 오메가는 바로 넓이 입니다.
# 도보로시내, 바로옆 플로렌츠역에서 까를로비바리, 택시로 근처 중앙역에서 오스트리아행 기차까지 완벽했습니다.
# 너는 침실 무드등이랑 형광등 중에 무엇을 켜는 걸 좋아해?
# 추위에는 손과 발을 내놓지 않도록 합니다.
# 영화 속에서 보던 유럽의 클래식한 멋이 가득한 집이었어요.
# 어떤 일이 있어도 약속을 연기하지 말거라.
# 참고로 코로나19와 관련한 한국의 대처를 소개한 독일 언론의 주요 보도 사례를 모아본다.
# 대구와 부산 중에서 내일 더 더운 곳을 알려줘.
# 화장실, 침대, 주차까지 다 너무 완벽했어요
# 그쪽은 잠금장치랑 침입 경고장치 중에 어떤게 더 중요한 것 같나요?
# 비 올 땐 높은지대에 텐트 쳐. 낮은 지대는 안돼.
# 내일이랑 모레 중에 언제 영화를 보기로 했지?
# 평일에 시티오브런던의 로이즈 빌딩 근처로 평일에는 매일 아침에 출근하였습니다.
# 감기 말고 여름에는 식중독 조심하기로 해요.
# 영어를 나름하고 외국인들과재밌는밤을보내고싶은 분에게 강추합니다.
# 집 바로 앞에 큰 건물이 있는데 그게 마트입니다.
# 대학후배 결혼식장에는 늦게 가지말고 일찍 가십시오.
# 결국 경제를 살리는 힘도 국민에게 있습니다.
# 안방이랑 작은방 주에 네가 편하게 잘 수 있는 곳이 어디니?
# 아침 산책으로 카를교까지 얼른 다녀올 정도로 넘넘 좋았습니다.
# 비무장지대(DMZ) 인근 뛰어난 생태·문화·역사자원을 생생하게 체험할 수 있는 ‘DMZ 평화의 길’ 노선이 올해 7개 추가 개방된다.
# 습도 높을 때는 사람 많은 곳에 가지 말아라.
# 집전체라는 느낌보다는 별채로 되어있는 공간입니다!
# 국내 학회 메일이랑 해외학회 메일이랑 비교하면 누가 더 숫자가 많지?
# 아토차역에서 600미터 정도 언덕길이라 올때는 좀 힘들듯해요.
# 이러한 성과를 바탕으로 올해 행정안전부에서 주관한 ‘2020년 골목경제 회복지원 사업 우수사례’에서 충청북도 청주시와 함께 최우수상으로 선정되는 영예를 안았다.
# 삼촌이 이 시간대에 보고싶은 티비 프로그램이 뭐여요?
# 스팸 메일함 저장 가능 용량이 어떻게 되나요?
# 위치, 분위기, 호스트 다 완벽하나 사진보다 크기가 작아요
# 언제 네이트 메일이 싸이월드랑 연동이 끝날까?
# 현재 안개는 한계령과 미시령 중 어디에 끼어있나요?
# 이번 로봇산업 선제적 규제혁신 로드맵은 디지털 뉴딜을 뒷받침하고 코로나로 인한 위기의 안정 및 언택트 로봇 경제 육성에 도움이 될 것으로 기대된다.
# 한메일 서비스가 언제까지 지속될까?
# 때문에 첫날 무척이나 당혹스러웠었어요.
# 특히 옥상에서 본 새해 불꽃은 환상적이었다.
# 그리고 창밖으로보이는 경치도 나무나도 좋았다
# 1층에는 다른 주민분이 사시고 2층이 숙소입니다.
# 방음이 안돼서 서로의 유튜브 소리를 공유합니다.
# 숙소의 시설은 물론 최신식에, 깔끔 그 자체였습니다.
# 엘리베이터가 있어 8층까지 이동하는데는 너무 편합니다.
# 아침밥도 무지 맛있었고 위치는 최고입니다!
# 민박업자 상시거주, 위생·안전기준 준수 등의 조건도 붙는다.
# 일단 위치가 좋아서 웬만한 장소는 이동하기 편해요.
# 정부 기관에 전달할 메일은 한메일을 이용하지마
# 대신 다른 공항 노선이 닿는 곳들과는 약간 거리가 있습니다.
# 황사는 며칠간 진행되었습니까? 지난해에.
# 도쿄 주민분들 사는 완전 주거지 같습니다.
# 개인적으로 여태 가본 숙소중 가장 예뻤어요
# 제가 휴가일 때 강수확률은 몇 퍼센트 입니까?
# 호스트의 친절함과 빠른 응답에 감사드립니다
# 국내 업체가 개발한 실시간 유전자 증폭 검사법은 하루 걸리던 검사를 6시간으로 줄였다.
# 둘 중 접속 가능한 게 있을까? 네이트 메일이랑 네이버 메일
# 부모님하고 약속한 거는 깨지 말고 지켜.
# 덕분에 우리는 워싱턴에서 좋은 추억을 만들 수 있었습니다
# 산책 계획이 아침에 있으십니까, 오후에 있으십니까?
# 내부의 예술품들은 현대미술관을 떠올리게합니다.
# 태풍 오면 배 타면 안된다.
# 에어컨 희망온도를 몇도로 설정해놨어?
# 지하철역 바로앞이라 이동할때 엄청 편해요!
# 무엇보다도 마치 제가 로컬 주민이 된듯한 느낌을 받을수 있었습니다.
# 찬물로 세탁하지마
# 저는 동생들과 2주 동안 이 숙소에 머물렀습니다.
# 내일 마지막 수업이 몇 시에 시작하는지 아시나요?
# ‘민생’과 ‘개혁’이라는 국민의 요구에 부응할 때 ‘협치’의 성과는 더욱 빛날 것입니다.
# 무엇보다 호스트의 친절함이 감동이었어요!
# 메일을 받은 메일함에 최대 몇 통까지 보관 가능한지 알아야합니다.
# 프라이팬, 냄비, 큰냄비, 인덕션렌지있고요,
# 교통이 편리하고 슈퍼마켓 등 가까운 위치에요!
# 그때마다 국민들께서 힘과 용기를 주셨습니다.
# 여름엔 음식 남기지 마세요.
# 와디즈에서 보내는 광고 목적의 메일은 차단해줘
# 다른 방은 그냥 평범한 사이즈 방이였어요!
# 당신 잊지말고 조명등 밝기 낮춰서 사용해요
# 그리고 무엇보다 집이 맘에 들었습니다.
# 가성비 생각하신다면 이 곳 추천드립니다!
# 다만 샴푸와 씻기 위해 필요한 물품은 챙겨오세요.
# 창문이 약간 얇아서 잠잘때 조금 찬바람이 들어옵니다.
# 체크인은 무조건 나무로 된 문 앞에서 하셔야 하세요!
# 호시우역과 가까워 신트라에 가기 편합니다.
# 너가 친구랑 해외 여행 가기로 한건 이번달이야 다음달이야?
# 하지만 개인실의 단점과 와이파이가 방에서 잘 안되는 단점이 있습니다.
# 구조 침구  도톰한 샤워 수건까지 최고였어요
# 요즘 유행하는 장화 스타일 알려줘.
# 그리고 빨래도 부억도 자유자재로 쓸수 있었고요
# 강릉 과학산업단지 사고와 같은 수소 사고가 재발하는 것을 막기 위한 대책도 마련됐다.
# 한시간 전에 취소하면 환불이 안되니 그때 영화 예약 취소하지 마세요.
# 정부가 코로나19의 재확산을 막기 위해 20일부터 다음달 5일까지 기존보다 다소 완화된 형태로 ‘사회적 거리두기’를 지속한다.
# 당신 잊지말고 에어컨 틀때 선풍기도 틀어놔요 대신 가습기는 놔둬요
# 팝업으로 뜨는 메세지, 문구 잘 보시고 이용하세요.
# 며칠간입니까? 작년에 황사가 진행된 일수가.
# 마드리드에서 가성비있는 숙소를 찾으시는 분은 이곳을 추천드려요!
# 신한카드 청구서를 메일로 오게 하고 싶은데, 뭘 해야하나요?
# 주중과 주말 중에 언제 소개팅을 하러 가시나요?
# 다만 길눈이 없는 초행자에게는 찾기가 좀 힘들었습니다.
# 식탁 위 말고 냉장고에 음식 보관하세요. 날씨가 더울 땐.
# 한가지 아쉬운 점은 전체적인 불이 한국 일반 가정집에 비해 어두운 편입니다.
# 생각보다 정말 좋은 숙소에서 3박 동안 잘 쉬었습니다!
# 다만 체크아웃 후 짐을 맡기는게 약간 어려워요
# 폭풍칠 때는 나가면 안돼.
# 방은 좁지만 혼자 쓰기 좋은 정도에요.
# 이와 함께 정부는 신종 코로나 하루 진단검사 물량을 이달 말까지 1만건으로 늘리기로 했다.
# 다른 계절엔 다시 찾을 의향이 있습니다.
# 교수님께 보낸 걸 어떻게 교수님이 읽으셨는지 확인하지?
# 책 읽을 때 형광등 켜놓지 마라고 경고했어
# 아울러 외국인들이 많이 이용하는 인력사무소에 대해 대기 장소 운영 적정성, 방문 구직자 마스크 착용, 대기 시 거리 두기 등 방역수칙 준수를 점검한다.
# 식사 하기 전에 운동을 할까, 하고 나서 할까?
# 방은 깨끗하나 주인의 생활공간임이 느껴집니다.
# 지원단은 ▲1만여명의 연구인력 ▲약 3만개의 연구장비 ▲그간 축적된 기술 등 공공연구원이 보유한 가용역량을 활용해 소부장 기업을 지원한다.
# 두명이서 지내기엔 딱 적당한 크기였습니다.
# 브라질의 교육기관들이 사용하는 메일 코드가 뭐야?
# 익일 예정된 실외활동에 대한 점검하고, 미세먼지 예보 상황 및 농도변화를 수시로 확인한다.
# 뮌헨에 또 오면, 난 다시 이곳을 찾을 것.
# (특고·프리랜서) 2019.12월~2020.1월 기간 모두 특고·프리랜서로 활동했어야 하는 것인지?
# 먼저 소비심리 및 경기위축으로 취업여건 악화가 우려되는 저소득층은 2만명 더 늘린 7만명에, 청년 대상 취업성공패키지는 3만명 더 늘려 총 8만명에게 지원을 확대한다.
# 다른 지역으로 이동하기에는 불편함이 조금 있습니다.
# 프랑크푸르터 룬트샤우 온라인판은 2월 26일 ‘한국, 법치국가의 한계 시험 중’이라는 제목의 기사에서 코로나19에 대한 중국과 한국의 대응 상황을 비교했다.
# 코나 시내와도 가깝고 매우 깨끗한 숙소 입니다!
# 전체건물중 방 1개이고 세탁기,건조기 공용입니다.
# 주요 상품인 전·월세 주택 자금 융자는 주거 부담을 고려해 상한액을 1억 원까지 높인다.
# 관광지 대부분을 한 호선으로 갈수 있습니다.
# 그대가 원하는 에어컨 바랍의 방향이 왼쪽인가요 오른쪽인가요?
# 비 올 때 빨래하면 건조기 쓰기로 하자. 그냥 두면 안돼.
# 형광등을 리모트 콘트롤 하는 방법이 뭐야?
# 세탁건조기 쓰면 안돼
# 이 곳에서 저의 부모님과 누나가 1박 있었습니다.
# 메일 주소에 어떤 특수문자를 넣을 수 있지?
# 너희 집 가스레인지 한달에 얼마 나오니?
# 교수님 컴퓨터가 고장났으니, 메일보다 전화를 드리는 것이 좋을거야.
# 이들은 공수처 직제편성과 대외기관 협력 등 조직 업무, 공수처 수사·공소 제기 관련 규정 마련 등의 업무를 지원할 예정이다.
# 마치 날개를 단거처럼 가뿐한 몸과 마음으로 그의지1이 입성할 수 있었죠.
# 네이버 메일 계정은 최대 몇개 만들 수 있지?
# 유럽여행 중에서 가장 깨끗한 집이었어요.
# 지역경제도 큰 걱정이 아닐 수 없습니다.
# 테르미니역 근처로 숙소를 찾고 있는 여자분들께 특히 추천합니다.
# 라니냐 현상의 가장 큰 원인 알려줘.
# 이번 주말에 제주 지역 강수량을 예측해주세요.
# 아웃룩을 리눅스에 어떻게 설치해?
# 하지만 휴원기간 동안 어린이집의 아동 돌봄을 필요로 하는 보호자는 어린이집 긴급보육을 이용할 수 있고, 어린이집 내 방역을 위한 소독 실시 및 급·간식도 평상시와 같이 제공한다.
# 규제샌드박스 임시허가·실증특례 적용 융합신제품과 산업융합 신제품 적합성인증 신청제품이 지원 대상이다.
# 장마 오기 전에 하수구 청소 하지? 놀지 말고.
# 에어비엔비를 사용할 때 호스트와 이메일을 통한 연락은 하지마
# 관광지에서 조금 떨어진 주택가입니다 가까운 지하철역까지 10분정도 소요됩니다
# 당신이 싫어하는 것은 더위인가요 아니면 추위인가요?
# 화산국립공원에 가깝다는 점도 큰 이점이구요.
# 테라스와 침대에서 에펠탑을 볼 수 있습니다.
# 대문말고 현관문 잠금장치 점검 안 해도 되겠어?
# 방에 히터가 있긴 하지만 방의 공기를 완전히 데우기에는 어려운 듯 해요!
# 임대사업자의 주요 의무사항인 임대의무기간 준수, 임대료 증액 제한 및 임대차계약 신고 의무를 중점적으로 점검하고 점검 지역은 전국을 대상으로 추진할 계획임
# 단언컨대 베를린에서 최고의 에어비앤비 호스트입니다.
# 그녀는 너무나 친절하며 진심으로 게스트를 대할 줄 아는 호스트 입니다!
# 모든게 완벽한게 한가지 단점이 있다면 피렌체 중심과 다소 멀다는 것입니다.
# 조식은 삶은 계란, 우유, 요거트, 씨리얼, 빵, 식빵, 잼, 뜨거운 물, 티백, 커피 등이 있었어요
# 북한 도메인의 메일을 보면 다른 정보를 모두 무시하고 주소만 저장하세요.
# 조금 귀찮으셨을 것 같은데 싫은 내색 하나 없이 흔쾌히 도움을 주셨습니다!
# 전용주차공간이 있고, 침실 그리고 욕실구조입니다.
# 참고로 대만에서 이정도 인테리어면 꽤 잘한거에요
# 자네 약속이 여름 겨울 중 언제 더 많나?
# 지하철에백년된먼지가있다는말은절대농담이아닙니다
# 매입약정 경험이 있는 사업자를 대상으로 1차 설명회를 경기 10일, 서울 11일, 인천 14일 잠정 진행하고 신규사업자를 대상으로 12월 중 2차 설명회를 진행한다.
# 그보다 제일 좋았던건 빠른 피드백인것같아요
# 3일을 머무르는 동안 전혀 불편함없이 사용했습니다.
# 호스트가 올린 사진 보다 훨씬 뷰가 좋아요
# 집안 곳곳에서 한국에 대한 관심을 찾아 보실수 있을겁니다.
# 9억원 미만 주택의 경우 토지 보다 현실화율이 낮은 상태(단독주택 52.4%vs. 토지 65.5%)로 역전현상은 현실화 기간에 걸쳐 점진적 해소
# 먼저 설 연휴 기간 동안 서울 용산구 국립중앙박물관에서는 한국의 전통장단과 외국 음악이 어우러져 신명나는 ‘설 놀이판 각자의 리듬: 유희스카’가 열린다.
# 대신 마트나 식당가는 조금 걸어가야합니다.
# 와이파이도 잘터지고 호스트 너무 감사해유!
# 무엇보다 위치가 너무 좋아 다음에도 이용할 듯 합니다.
# 주요 일정들이 겹치는 때가 언제야?
# 지난달 17일 중국인 어선원 수급 문제로 경영에 어려움을 겪는 근해안강망 어업인에게 지원한 12억 4000만원에 이어 추가로 187억 6000만원을 지원하는 것이다.
# 그리고 숙소에서 시내보다 비셰흐라드가 진짜 가까워요
# 긴급재난지원금은 마스크 5부제와 동일한 요일제로 시행함에 따라 12일 신청 대상은 세대주의 출생연도 끝자리가 2, 7번인 가구다.
# 트램 정거장도 숙소에서 엄청 가깝고 숙소랑 모든 관광지가 가까워요!
# 태풍 루사 피해액은?
# 그러나 편안한 집을 생각하신다면 만족하실거예요.
# 아, 방과 방 사이 말소리가 웅얼거리듯 들리긴 해요.
# 무엇보다 주인장이 너무 친절하셨습니다.
# 공공기관들도 감염병 극복이라는 사회적 가치 실현에 최선을 다해 주기 바랍니다.
# 중기부가 민간 지원을 받아 국내 소상공인·전통시장 상인, 중국 소재 우리나라 중소기업에 마스크 총 31만개를 긴급 지원한다.
# 경북 안동시는 유교문화자원을 활용한 사업 비전이 지역 특색을 잘 반영했다.
# 알려주십시오. 내일의 황사 지수.
# 내일 영화 보러가는 거 언제 시작하나?
# 이와함께 투기과열지구에서 9억원 넘는 주택을 살 때는 신고서와 함께 증빙자료도 제출해야 한다.
# 하지만 조금 아쉬운 점은 시부야, 신주쿠랑은 조금 거리가 있어요
# 시부야와 전철이 연결된 위치여서 여행하기 좋은 위치입니다.
# 깔끔한 원목 분위기와 예스로우면서 세련된 느낌을 가진 숙소입니다.
# 비 올 때는 흰 운동화 신으면 안돼.
# 깨끗한 곳을 원하시는분에게는 비추이구요.
# 방도 엄청 따듯했고 와이파이도 엄청 잘됩니다.
# 너무 관광느낌보다는 편안하게 일상처럼 지낼 곳을 찾는 분들에게 더욱 추천드립니다!
# 무엇보다 집주인이 친절하며 집은 청결합니다.
# FDA승인 뇌전증 치료제 ‘세노바메이트’, 지능형 소프트웨어 ‘닥터앤서’ 등 국가연구개발 우수성과 100선이 선정됐다.
# 위치는 시청 근처로 좋은 편이 었습니다.
# 그동안 지원되지 않았던 취업성공패키지Ⅱ유형에 참여한 중장년과 일반고 특화훈련과정을 수료한 사람을 채용한 사업주에게 고용촉진장려금을 지원한다.
# 위치는 사그라다 파밀리아 성당이 까탈루냐 광장보다 가깝습니다.
# 도보로 관광할 계획이라면 신타그마광장 근처를 추천합니다.
# 지난 10월 25일 천안 봉강천을 시작으로 용인 청미천, 천안 병천천, 이천 복하천, 제주 하도리 등지에서 조류인플루엔자 항원이 검출됐다.
# 호스트는 영어보단 스페인어를 더 잘하시는데 소통하는데는 지장없을거에요.
# 지금 거실 온도 확인하게 좀 알아봐바
# 사진에 나오는것이 거짓은 아니지만 아주 많은 시간이 흐른듯 보인다.
# 어떤 일정이 일요일로 계획되어 있나요?
# 1주택자가 2년 미만 단기보유 주택을 양도하는 경우 양도세 부담은 어떻게 달라지나요?
# 에어컨 작동 예약해놓은 시간 알려줘
# 2층 화장실은 샤워하기 조금 좁고 1층 화장실이 큽니다.
# 다시 전기를 키는법은 냉장고 오른쪽의 문 안에있는 두꺼비집에서 하얀레버를 시계방향으로 돌리면 됩니다.
# 파일 전송시 네이트 메일을 쓰는건 피해야해
# 건물은 정말 깔끔한 현대식이고 굉장히 안전합니다
# 정상화의 이익을 국민과 함께 공유하는 방안도 추진하겠습니다.
# 오늘 마련하는 금융 지원들이 하루가 급한 사람들에게 ‘그림의 떡’이 되어서는 안 됩니다.
# 북한 정부 기관에 어떻게 메일을 전송해야하는가?
# 편의성과 서비스에 감동할 수 있는 숙소라 생각합니다.
# 대한항공이랑 진에어 중 어디가 이메일로 티켓을 보내줬었지?
# 위치,의사소통,체크인만 정말 좋았습니다
# 학교 메일은 수신거부 하지마
# 기차 이용하실 분들은 산타루치아역 바로 전 역인 베네치아 메스트레역을 이용하시면 도보로 이동가능합니다!
# 그저 그런편 남자는 지내기 편리함 여성은 청결을 그렇게 신경안쓴다면 괜찮은 편
# 큰 신주쿠 역과의 거리는 꽤 있는 편입니다만 주위에 편의점과 슈퍼가 있어 편리합니다.
# 목욕물을 개인별로 좀 세팅하고 싶으니까 방법 좀 알려주세요
# 일자리 포털 워크넷(www.work.go.kr)에서 맞춤형 채용공고를 추천하는 ‘테마별 채용관’의 누적 방문자 수가 30만 명을 넘어섰다.
# 이번달에 내야 할 식기 세척기 전기 요금 알려줘
# 깊은 산속에 있는듯한 이 집은 밤에는 개구리와 새소리로 가득했다.
# 아내와 함께 여행을 했으며, 숙소를 정할때는 5가지를 고려합니다.
# 메일 관리를 할 때에는 리눅스 말고 윈도우를 설치하여 해주세요.
# 건조기는 신경쓰지말고 세탁기로 닦을 때는 꼭 세제 넣고 해야해
# 제 학교 성적표가 어느 이메일로 오도록 설정했나요?
# 또다시 하와이를 방문한다면 나는 이곳을 선택할것입니다.
# 선풍기 풍향은 어떤 명령어로 조정하나요?
# 눈 내릴 때 집에서 쉬지 말고 스키타러갈래?
# 페이스북과 트위치 계정을 연동하는 것이 하지 않는 것보다 더 좋을거야.
# 이번 특별교부세는 선별진료소 운영과 확진자 및 자가격리자 관리 강화 등 코로나19 감염증 확산 방지 활동에 필요한 비용을 지원하기 위한 것이다.
# 주말 날씨가 어때? 돌아오는 연휴에는.
# 숙소는 원베드룸으로 아기자기한 소품도 많고 예쁩니다.
# 숙소도 깔끔하고 침대도 푹신푹신합니다!
# 뜨거운물 말고 미지근한 물로 좀 목욕해봐
# 나의 첫여행에 부족함없이 너무 좋은 최상의 조건을 갖춘 콘도였다.
# 깨끗한 공간과 친절한 응대에 만족했습니다.
# 먼저 점포 재개장은 제출서류를 간소화해 코로나19 피해 점포 18만 9000개소에 최대 300만원을 신속 집행한다.
# 노후 건축물과 공공임대주택을 친환경 시설로 교체하고 도시 공간·생활 기반시설의 녹색전환에 2조4천억 원을 투자합니다.
# 플랫폼 사업자 등의 배타조건부 거래, 끼워팔기 등 신규 경쟁사업자의 시장 진입을 막는 정보통신기술(ICT) 산업 내 ‘경쟁제한’ 행위도 올해 중점감시 대상으로 선정됐다.
# 네이트 메일에서 전체 메일을 보내는 방법을 혹시 아니?
# 물론 숙소 시설과 청결도 등도 기본적으로 최고였습니다
# 지난해 혁신도시로 이전한 공공기관의 지역인재 채용률은 25.9%로 목표를 초과 달성했다.
# 거울 안 쪽 선반과 옷장도 활용할 수 있어요.
# 역이랑 가까워서 이동하기에도 편합니다.
# 무료라고 적힌 부분이 꼭 무료는 아닙니다.
# 전자레인지말고 가스레인지를 쓰면 어떄?
# 다음에 가시는 분들은 릴레이라이드, 우버 미리 가입하면 좋을듯 합니다.
# 아주 더운 여름만 피한다면 정말 좋은 선택이 될 것입니다!
# 삼월에만 몇 통의 메일을 받았는지 알려줘
# 한가지 아쉬웠던 점은 매일 게스트가 청소와 세탁을 해야 했던 점입니다.
# 앞으로 어린이 보호구역 내 신호등이 없는 횡단보도에서는 모든 차량이 의무적으로 일시정지해야 한다.
# 권력기관 개혁의 핵심은 견제와 균형을 통한 권력 남용의 통제이고, 이 점에서 공수처 설치, 검경수사권 조정, 자치경찰제 도입과 국가수사본부 설치는 한 묶음입니다.
# 위치 청결 서비스 호스트의 연락 모든게 완벽했습니다.
# 저는 대학교 친구 3명과 졸업여행을 목적으로 상하이를 방문했습니다.
# 언제 설악산 단풍을 봐야 절정이라고 할 수 있습니까?
# 최근 일주일간 40대 이하 확진자 비율이 52.2%로 나타났습니다.
# 아울러 국립대병원 12개소와 지방의료원 15개소를 중심으로 퇴원환자가 지속적인 건강관리를 받을 수 있도록 의료·복지서비스를 연계하는 등 지역보건의료기관 간 협력을 강화한다.
# 하지만 전반적으로 만족스러운 숙소였어요!
# 2월의 8억원과 비교하면 놀라운 증가세다.
# 침대도 두명이 이용하고 충분한 사이즈입니다!
# 언제가 백일 기념일이야?
# 청결도나 시설에서는 매우 만족 스러웠습니다
# 가족 여행은 이번달에 가기로 했니, 다음달에 가기로 했니?
# 집의 청결도 및 조용함, 그리고 화장실이 2개인 점이 좋았습니다.
# 그리고 친절한호스트에게서 좋은 추억 많이 남기고갑니다.
# 네이버 메일이랑 연동된 클라우드 서비스 알려줘
# 와이파이도 빵빵 뜨거운물도 빵빵 히터도 빵빵했어요!
# 위치가 좋고 호스트도 너무 친절합니다.
# ...
# 마드리드 중심지인 솔광장 애플스토어에서 걸어서 3분정도 걸립니다
# 위치, 가격, 호스트 뭐 하나 흠잡을 것이 없습니다.
# 지금까지 묵었던 숙소 중에 최고였습니다.
# 페이스북에 메일 주소는 비워두세요.
# 하지만 주변소음이 많이 신경쓰이시는 분은 밤에 잠을자기 힘드실수는 있어요!
# 네이버 메일을 받은편지함에 저장할 수 있는 최대 기간은?
# 그래서 2층 정도야 괜찮은것 같습니다.
# 에펠뷰는 아니지만 에펠탑을 볼 수 있는 마르스 광장과 아주 가까워요!
# 하지만 그로 인해 방에 개미, 바퀴벌레 그리고 파리가 잘 보입니다.
# 동네슈퍼 점주가 쉽게 교육을 받을 수 있는 정기적인 온라인 교육 제공과 함께 스마트슈퍼 모델 점포와 편의점 무인점포 현장 방문 프로그램이 도입된다.
# 백일 기념일 언제야?
# 언제가 자연어처리 학회 논문 마감일이죠?
# 메일 중 학회 홍보 메일은 답하지마
# 엑셀파일을 지메일에서 바로 읽는 방법을 알려줄 수 있어?
# 근처 버스 정류장에서 걸어서 4분정도입니다.
# 태풍 피해 액수 알려줘. 작년 여름 기준.
# 다음 번에 세비야에 또 온다면 반드시 이곳에 머물 생각입니다.
# 특히 공용화장실과 부엌이 굉장히 청결했습니다.
# 우리가 사월 한달 동안 학교에 몇통이나 메일을 보냈지?
# 침구가 너무 지저분하고 난방이 전혀 안되었음
# 미세먼지 높을 때는 그냥 나가지 말고 마스크 쓰자.
# 거래처 사람들과 만날 때 늦기 보다는 제시간에 도착해봐.
# 경북 차세대배터리리사이클링 특구는 짧은 기간에도 GS건설이 1000억원을 투자하는 등 지역경제 활성화 기여 측면에서 우수한 평가를 받았다.
# 비 올 때는 자전거는 타면 안돼.
# 숙소 바로 근처에 맛있는 아시안 푸드 음식점이 있는 것도 좋았어요.
# 다만 큰길 차가 많니 다니는길쪽의 집은 소음이 심합니다.
# 다만 집안 내부의 바닥 청결상태가 더러웠습니다.
# 모든 것이 게스트 위주인 숙소였습니다.
# 친절한 호스트이지만 이런 점은 반드시 개선을 요합니다.
# 중기부는 제도에 참여를 희망하는 중소기업이 창업기업 여부를 확인하는 데 필요한 창업기업 확인 업무의 절차도 구체화했다.
# 관계부처 장관들과 자치분권위원장, 균형발전위원장이 함께했습니다.
# 비의 종류 중에서 이슬비와 소나기 둘 중 골라야 한다면 뭘 선택할거야?
# 리스본에 오신다면 이 숙소 정말로 추천합니다!
# 대만 여행 중 이 숙소에 3박 4일동안 보냈습니다.
# 집 근처에는 기념품 파는 곳이나 레스토랑이 많이 있어서 식사하기 편리해요.
# 하루에 일정을 바쁘게 만들기 보다는 하나만 잡으렴.
# 하지 않기로 해. 눈 올 때 운전하기.
# 니가 카카오톡에 사용 중인 로그인 메일 주소 알려줘
# 먼저 2·3차 자동차 부품업체를 원청업체 부도로부터 보호하기 위해 외상 매출 채권의 효력 상실 위험성을 제거한 ‘팩토링’을 신규로 추진한다.
# 모든 국민이 혜택받도록 생태계 서비스를 확대한다.
# 기온이 어떤가요? 연평균 토론토는.
# 결제 메일에 담기는 내용이 어떻게 되나요?
# 보통의 숙박기관으로 변질된 요즘의 에어비앤비의 숙소 중에서,  호스트가 직접 생활하는, 진정한 의미의 에어비앤비 숙소를 만날 수 있었습니다.
# 본섬내에선 여행객들이 주로 머물기 때문에 이는 운인것 같아요.
# 그 때 같이 보낸 저녁식사시간이 정말 좋았습니다.
# 도쿄에서 이만한 가격에 집 한채를 빌리는 것 자체가 만족스러웠습니다.
# 지메일 자동완성 기능의 성능에 대해 평가해줘
# 장마 곧 오니까 그 전에 놀지 말고 하수구 청소 하세요.
# 기차역에서 가깝고 매우 훌륭한집입니다.
# 다른 분에게도 적극적으로 추천하고 싶은 장소입니다.
# 국가별로는 브라질이 3015만 달러(약 369억원)로 가장 높은 비중인 13.3%를 차지했다.
# 화장실엔 샤워부스와 변기, 세면대, 가열이 되는 수건건조대가 있습니다.
# 묵었던 에어비엔비 중에서 최고였습니다,
# 또한 국내 유통 중인 액상형 전자담배 112개 제품을 대상으로 중증폐손상 유발 의심성분 6종 및 니코틴에 대한 성분 분석도 진행했다.
# 숙소 곳곳에서 세심한 배려가 느껴지는 곳.
# 자주 약속날짜를 바꾸면 헷갈리니까 바꾸지 마.
# 엘리베이터 사람도 탑승 가능하구 집도 사진 그대로 입니다.
# 매력적이고 편리한 방한 관광, 1100여개 기업 다양한 혜택 제공
# 4인 기준으로 지역가입자 가구는 25만4909원, 혼합가구는 24만2715원 이하여야 한다.
# 또 실직이나 휴폐업 등 위기상황이 발생한 저소득 위기가구에 긴급 생계비를 지원하고, 건강보험료는 하위 20%를 대상으로 3개월간 50% 감면한다.
# 리프트가 없다는것만 빼고는 모든게 완벽한 숙소입니다.
# 약간의 업무를 병행하는 나는 불편했다.
# 대규모로 일어나고 있는 신천지 집단 감염 사태 이전과 이후는 전혀 다른 상황입니다.
# 완벽한 위치 높은 청결도 멋진공간 친절함 모든게 좋았습니다
# 왠만한 관광지 및 갤러리는 다 갈수있어요.
# 사라의 숙소는 위치도 완벽하고 공간도 완벽합니다.
# 내가 메일을 제일 많이 보낸 거래처가 어디지?
# 이렇게 작은 방에 있을건 다 있는게 신기했어요.
# 아파트 구조가 매우 안전하므로 여성분께 추천
# 정부는 22일부터 위험도가 낮은 야외공간인 자연휴양림, 수목원 등 시설에 순차적으로 입장을 허용할 계획이다.
# 모던한 느낌으로 모든 사람들이 좋아할만한 집입니다.
# 그리고 독립된 공간이 상당히 맘에 들었습니다.
# 기업 체감심리를 가리키는 기업경기실사지수 역시 74로 전달보다 10포인트나 상승했다.
# 지금 뉴스 방송 하는 채널이 어디야?
# 주인분이 영어는 못하시지만 굉장히 친절하십니다.
# 군인 친구가 받을 메일엔 이상한 내용이 있어선 안돼
# 개막식에서는 올해 우리술 대축제 홍보대사로 위촉된 소녀시대 유리 씨가 우리술을 주제로 유명 셰프와 이야기를 나누며 요리 대결도 펼친다.
# 반드시 받은메일함이 아닌 보낸메일함의 메일을 주기적으로 백업합시다.
# 고위험시설 중 유통물류센터는 기존에 시행되고 있던 핵심 방역수칙 의무화 조치가 그대로 유지된다.
# 원격수업은 우리부가 마련한「원격수업 운영 기준」에 따라,
# 국가의 대응 능력이 국력이고, 국민의 시민의식이 국격입니다.
# 특히 호스트가 친절해서 에어비엔비 메신저로도 연락이 아주 잘됩니다.
# 세탁에 세제 정도껏 쓰면서 해
# 요즘 네가 즐겨 보는 뉴스 채널이 뭐야?
# 나 카카오톡 연동한거 학교거로 했었냐 회사거로 했었냐?
# 단점은 침대가 너무 높이있어서 사다리를타는게 좀힘들었단거?
# 밤에 야외 테라스에서 별을 볼땐 정말 최고였습니다
# 호스트가 사는 주택에 방 한칸을 빌리는 거였어요,
# 역시 샤워시설이 좁은 것이 아쉽지만 가격대가 싼편이기 때문에 감안하는 점입니다.
# 회사에서 온 건 그냥 열어보지마
# 감염병 전문병원과 국립 감염병연구소 설립도 추진하겠습니다.
# 다만 8시 이후에는 모두 문을 닫아요.
# 저한테 너무 자주 전화 거시는 것 같은데 그만해주세요
# 생각보다 더 작은 숙소에 놀랄수 있습니다.
# 이번주와 다음주 중에서 축구경기는 언제 하는거야?
# 수건이랑 이불에서 퀴퀴한냄새도 좀 났네요
# 호스트는 매우 친절하였고, 요청에 대한 응답도 매우 빠릅니다.
# 앞으로는 약속 일정을 변경할 때 까먹지 말고 미리미리 얘기해라.
# 내일 친구랑 만나기로 한 약속 장소가 어디야?
# 좋은 위치에 비교적 인테리어에 신경을 많이 쓴 정원이 있는 집이었다.
# 저기요 안방 조명은 어떻게 켤 수 있죠?
# 기획재정부가 주관한 제약회사 대표회의 자체가 없었습니다.
# “한국 코로나 테스트, 드라이브 스루 SMS 로 결과 통보, 관리혼선에 뒤늦게 테스트 비용논란인 일본과 대비” 2월 29일, 독일 제1 공영방송 ARD
# 그 덕분에 신혼분위기는 더욱 무르익었죠.
# 숙소 호스트님이 진짜 친절하시고 좋으셨어요!
# 호스트 아주머니께서 영어도 하시고 아주 친절하십니다.
# 그리고 동네 맛집이나 관광정보 제공은 없었어요
# 내일 오전 가장 이른 스케쥴이 뭐에요?
# 네이버랑 네이트 중에 뭐가 더 메일 첨부파일이 더 빨리 가?
# 위치 청결 호스트 친절도 어느것하나 나무랄것이 없어요!
# 숙소와 체크인 장소가 좀 다르니 참고하세요.
# 내일 출장 시간이 어떻게 되시는지 말씀해 주시겠어요?
# 변화를 기회로 삼고 도전하는 젊은이들에게 더 많은 기회가 주어질 때 기업과 국가 경쟁력을 높일 수 있을 것입니다.
# 와이키키나 알라모하나와의 접근성도 좋습니다.
# 에어컨한테 음성명령하려면 어떻게 해야돼?
# 옆건물 1등에 꼬치랑 고로케같은더 파는 곳있는디 훌륭합니다.
# 다음주 저녁 약속 몇번 있어?
# 집주인과의 커뮤니케이션도 아주 원활하였어요.
# 위치가 정말 좋고 호스트께서 너무 친절하세요
# 마당에서 가끔 보이는 귀여운 고양이와도 즐거운 시간을 가질 수 있습니다.
# 다음에 기회가 또 생긴다면 다시 머물거에요
# 하지만 세명이서 이용하기에 잠자리가 조금 불편했네요!
# 집 전체는 낡았는데 숙소 안에만 청결한 느낌입니다!
# 바이러스 감염 예방을 위한 보건용 마스크의 수급에는 큰 문제가 없는 것으로 판단했다.
# 현지와 관련된 유용한 정보를 얻을 수 있었습니다.
# 먼저 위치는 빅토리아역 근처라기에 많이 멀어요.
# 여러 노선의 버스가 다니는 정류장이 건물 입구 바로 앞이에요.
# 오빠 지금 집밖이 더 습할까 집안이 더 습할까?
# 숙소위치는 시내와 10분거리로 굉장히 가깝습니다
# 저녁에는 갈매기 울음 소리가 주기적으로 들려서 수면에 방해될 공산이 큽니다.
# 덕분에 프라하에서의 좋은 추억을 만들수있었어요.
# 또한 정유정 작가의 ‘28’ 등 기존 책의 표지를 새롭게 바꾼 다시, 이 책 10종이 제작된다.
# 공간도 무척이나 넓어서 정말 쾌적합니다.
# 이날 퇴소한 교민들은 미리 준비된 버스 20대를 이용해 5개권역(서울, 대구·영남, 충북·대전·호남, 경기, 충남)으로 이송됐다.
# 이번주에 동기 모임이 있으신가요 다음주에 동기 모임이 있으신가요?
# 깔끔하고 딱히 단점을 찾을 수 없는 숙소입니다.
# 거래처에서 온 메일은 지우지 마세요
# 2010년생 포함 이후 출생 어린이와 1940년생 포함 이전 출생 어르신, 장기요양급여 수급자, 장애인은 대리구매가 가능하다.
# 드론 실명제는 최대이륙중량 2kg을 넘는 드론 소유자에게 기체신고를 의무화하는 것이다.
# 재해피해는 어떤 태풍이 제일 컸나요? 한국 역사 중에서.
# 5단계 주의보, 경보 발령 해제가 되면 조치사항에 따른다.
# 나카메구로 역에서 걸어서 3분정도의 거리, 집 근처의 수많은 식당들, 매우 친절한 스태프들, 무제한으로 제공되는 숙소의 물품들까지.
# 여름 겨울 중 언제 약속이 더 많으시죠?
# 공항픽업 서비스나 주변 볼거리 먹을거리 안내가 특히 유용했습니다.
# 너가 느끼기엔 집안이 더 습한 것 같아, 집밖이 더 습한 것 같아?
# 화장실도 깨끗한 편이었고, 가격대비 만족합니다.
# 12월에는 과천 지식타운에서 645가구, 고양 장항 1438가구, 성남 대장 707가구, 위례에서 294가구 등이 분양 예정이다.
# 이번 지원 대책은 ‘재난 및 안전관리기본법’과 과기정통부 소관 전파, 통신 및 우편 등 법령에 따라 지원이 실시된다.
# 그리고 문 잠고 여는 것을 체크인할때  꼭 숙지하세요
# 약속 가능한 시간이 오일 저녁이면 어떻게 되시나요?
# 정부가 22일부터 내달 5일까지 종교시설, 실내 체육시설, 유흥시설 등에 대한 운영 중단을 권고했다.
# 너는 블루투스 스피커하고 피씨용 스피커 둘 중에 뭐가 더 좋아?
# 알려줘. 엘니뇨 현상의 가장 큰 원인.
# 민간임대주택법 시행규칙을 개정해 오피스텔 임대사업자의 실제거주 확인방식을 다양화한다.
# 주변의 그랜드센트럴에서 아침 먹는 일정이 좋았습니다.
# 오늘 서울 밤 최저기온 검색해서 찾아줘.
# 대표적인 사업으로는 디지털 뉴딜 분야의 ‘카자흐스탄 알마티 및 우즈베키스탄 타슈켄트 도시교통 혁신기술 도입 지원사업’이 있다.
# 이용하고 싶은 체육시설 ‘장애인 전용 공공체육시설’, ‘공용 공공체육시설’ 순
# 코로나바이러스감염증-19(이하 ‘코로나19’)에 감염된 노동자가 산업재해로 인정을 받았다.
# 작은 방에 이층침대 하나와 큰방에 더블침대 하나가 있구요
# 차 없이 시내까지 버스로 기본 두시간은 걸려요, 출퇴근 시간은 막히기도 엄청 막히구요.
# 까르푸, 카지노 대형 슈퍼 있었던 것도 괜찮았습니다.
# 지급액은 본인과 배우자의 근로소득, 사업소득, 종교인소득을 합한 ‘총급여액 등’을 장려금 산정표 상의 해당 구간에 적용해 산정된다.
# 장점은 좋은 위치, 가격, 뛰어난 편의 시설, 집 구조 등 너무 많네요.
# 우리가족은 어른4명과 아이2명이 머물렀습니다.
# 단점은 로마가 대중교통이 한국에 비해 완전 불편합니다.
# 와디즈로부터 오는 메일 중 광고는 받지마
# 당신 잊지말고 아침에 샤워는 차가운 물말고 꼭 더운물로 하세요.
# 올해 국가공무원 공개채용 선발 인원이 6110명으로 확정되었다.
# 인천공항 예상 강설량 알려줘.
# 기프트카드의 온라인 신청은 누가 할 수 있나요?
# 단풍으로 유명한 산을 알려주세요.
# 호주의 좋은 가정집에서 묵는 느낌이었어요.
# 친구랑 둘이 동시에 케리어를 열 수 없을정도로 좁아요.
# 지금까지 머물렀던 숙소 중에 최고인 것 같아요!
# 베를린에 잠깐 머무신다면 이 숙소를 추천해요.
# 7. 감염병 보도 시 주의해야 할 표현
# 숙소는 중앙역앞 공원옆에 위치하여 도보로 이동이 가능합니다.
# 홍보메일을 학회에서 더 자주 보내, 저널에서 더 자주 보내?
# 자꾸 실내 온도 높이려고 하지마
# 운치있는 아파트로 세월의 흔적이 자연스러운곳입니다.
# 경쟁력 강화방안에 따르면 내년 인천공항 슬롯은 시간당 5회 늘어난다.
# 한편 유통업계가 주도하는 코리아세일페스타 추진위원회는 오는 23일 주요 소비재별, 업태별 할인행사 및 이벤트 계획을 발표할 계획이다.
# 셋째 열쇠로 문을 여는게 조금 어렵습니다
# 나한테 메일 보낼 때는 다른 메일 말고 네이버 계정으로 보내줘.
# 민감한 내용을 전달할 땐 전체 메일을 통해 보내선 안돼
# 또 호스트분이 주변 식당 정보와 와인집으로 초대한것이 매우 좋았습니다
# 내일 동아리에서 있는 모임 언제 열리는지 아세요?
# 호스트가 매우 친절하고 방이 굉장히 아늑합니다.
# 메스트레역에서 정말 걸어서 3분 걸려요!
# 집 바로 앞에 맥도날드와 역, 마트가 있어 아주 편리합니다.
# 찍히고 싶지 않으시면 회사 상사와의 저녁 약속에는 늦지 마십시오.
# 추석 기간 중 날씨는 어떻습니까?
# 또한 호스트의 빠른 응답과 깔끔한 숙소도 훌륭했다.
# 한국인이 신오쿠보쪽 묵을 예정이라면 정말 좋은 장소입니다!
# 또한 입국자는 모바일 ‘자가진단 앱’을 의무적으로 설치해 입국 후 14일간 매일 자가진단 결과를 제출한다.
# 여름이면 뜨거운 낮에 보지말고 선선한 저녁에 보는 걸로 합시다.
# 사람 중심의 안전하고 행복한 도시를 만들 것입니다.
# 특히 기업이 특별연장근로를 신청하면 3일 이내 처리가 원칙이나 사태가 급박할 경우 사후승인을 허용한다.
# 숙소도 깨끗하고 거실 침실 부엌 화장실 따로있는 꽤 큰숙소에요.
# 깔끔한 숙소,친절한 호스트 센스있는 인테리어도 아주 맘에 들었습니다
# 매일 집에서 나올때, 다시 들어갈때 안뜰 때문에 더 행복했어요
# 정말 저와 제 친구는 만족하는 숙소였습니다.
# 뜨거운 물을 다 쓰면 30분뒤에 다시 씻기를 도전하세요
# 차세대 AI 개발을 위해서는 2022∼2026년 총 9286억원 규모의 RD 사업 예비타당성 조사를 추진한다.
# 이 외에도 침실 문이나 에어컨 등 내부 시설이 오래되어 교체가 필요한 느낌입니다.
# 특히 직접 만든 빵은 정말 맛있었어요.
# 작년에 우리나라에는 몇 개의태풍이 왔었어?
# 노트북으로 연결한 인터넷 신호는 가끔 끊겼어요.
# 학교가 보내는 메일의 도메인 주소는?
# 계획되어 있는 내일 오후 일정이 몇 개야?
# 제주 지역 강수량이 궁금합니다. 지난 주말에.
# 뱅글뱅글 돌아야하는 다소 좁은 계단입니다.
# 현관문 잠그지 말아 줘
# 무엇보다 숙소의 위치가 관광지 등 접근성이 좋았기 때문에 만족했습니다.
# 데이터 저장장치(SSD)와 레이저 프린터 수출 역시 각각 254.5%, 12.9% 증가했다.
# 잠시 지낼 만한 곳이 필요하다면 추천드립니다.
# 결제 메일과 공지 메일 중 수신 거부할 수 있는게 있을까요?
# 문체부와 영화진흥위원회는 영화기금 변경을 통해 확보한 170억 원을 코로나19로 피해를 입은 영화산업 각 분야에 투입한다.
# 연수 일정이 있다고 한게 이번주야, 다음주야?
# 정확도나 빠르기등 지메일 자동완성 성능은 어떤지 알아?
# 이번 주 업체 일정 시간이 어떻게 돼?
# 북한 도메인의 메일을 보면 제목은 저장하지 않고, 주소를 저장하세요.
# 에어비앤비랑 트립닷컴 중 어디가 더 메일링 광고를 집행하는 것 같아?
# 다만, 신규 공무원증 발급 시까지는 기존 공무원증을 병행해 사용한다.
# 현관앞에 아기자기한 레스토랑이나 카페들도 좋습니다!
# 한시적 조세감면…카드 소득공제율 2배 상향·승용차 개별소비세 인하
# 야, 네가 중요하게 생각하는게 환기냐 난방이냐
# 안개 낄 땐 운전금지입니다.
# 다만 제로페이 사용금액은 전통시장, 대중교통, 도서·공연비·박물관·미술관 사용분과 달리 신용카드 소득공제 한도액을 초과하는 금액에 대해 추가 공제는 안된다.
# 이층방에 이어진 테라스가 하나 더 있고요.
# 테라스의 아름다운 뷰는 선물과도 같습니다
# 현재 운용 중인 광주·전남 한국전력 모펀드를 벤치마킹, 일부지역에 시범조성 후 확대할 예정이다.
# 시중 유동성을 그린뉴딜 분야로 유도하기 위한 녹색금융 활성화 방안도 논의됐다.
# 물론 저는 소리에 조금 민감한 편이에요.
# 휴면 계정으로 전환되는건 네이버 메일에 얼마나 접속을 안했을때 인가요?
# 집이 무슨 모델하우스처럼 깨끗하고 예쁩니다.
# 시·도지사님들도 화상 연결로 참석했습니다.
# 2018년 15개 부처와 모든 지자체에서 운영 중인 기업민원 보호헌장은 지난해 기재부·과기부·농림부·금융위·방통위·방사청·병무청 등 7곳에서 추가로 제정했다.
# 개인적으로는 정말 만족한 숙소였습니다.
# 하늘이 보이는 아름다운 침실과 충분한 휴식을 즐길수있는 거실이 있습니다.
# 좋은 위치, 멋진 뷰, 만족스러운 청결도 잘 머물다가요.
# 우리는 함께 긴밀히 협력함으로써 이를 극복할 것이라고 확신한다.
# 호스트는 매우 친절하였고 의사소통에 원활합니다.
# 지메일 연동이 가능한게 트위치니 유투브니?
# 방문 하실 분들은 미리 숙지하고 가세요.
# 내일 새벽 안개 걷히는 시간은?
# 좋은 파도가 들어오는 때에는 다른 것 말고 서핑하도록 해.
# 롱디하느라 자주 보지도 못하시는데 여자친구하고 약속은 미루지 마시지요.
# 후기기 좋은것에는 분명한 이유가 있어요.
# 근교투어 많이 하는 경우엔 시내가 확실히 접근성이 좋아요.
# 작은 금고 두개가 있으며 노트북은 보관할 수 없는 규격입니다.
# 엔드라이브에 문제가 발생해서 네이버 메일에 지드라이브를 연동해야해
# 배달의 민족 결제 내역을 메일로 받고자 하는데 안내 부탁드립니다.
# 욕실 수압이 약한 것과 샤워부스에 비누조차 놓을 선반이 없는 건 아쉬웠어요.
# 벌레도 없고 역이나 여행지를 다니기에 좋은 위치입니다.
# 그녀의 방은 정말 아름답고 깨끗합니다.
# 욕실청소가 좀 덜 된게 아쉽긴했지만 넓은 공간과 뷰가 최고입니다!
# 하지만 단점이 신경 안쓰일 정도로 너무 좋은시간 보냈습니다.
# 한국분들 로마 오시면 여기 꼭 이용하셔요.
# 광고 메일은 왜 자동으로 분류 되고 있나요?
# 겨울엔 수도관 보온합시다. 방치하지 말고.
# 현지인들이 자주가는 맛집, 구글평점도 훌륭한 곳들이었습니다.
# 2020년도 예산이 역대 최대 규모인 512조 3천억 원으로 확정되었습니다.
# 날짜가 어떻게 됩니까? 강원영동에 비 오는 날.
# 광장 너머 상조르주성 경관도 만족스러웠구요.
# 집도 오래된 외관과 달리 너무 깔끔하고 예뻐요!
# 이탈리아 여행중 제일좋은 에어비앤비하우스였어요.
# 정부가 코로나19 조기극복을 위한 민생 안정 및 소비여력 지원을 위해 2조 9000억 원을 투입한다.
# 엄마 생일 날짜가 몇 월 며칠이야?
# 화장실은 변기에 앉으면 다리가 벽에 닿을 정도 입니다.
# 특히, 청년정책 컨트롤타워인 청년정책조정위원회에도 청년위원을 위촉할 방침이다.
# 당신 잊지말고 보일러 점검 꼭 구월말고 시월 되기 전에 끝내세요.
# 올해 처음 개최되는 투자유치설명회는 전문투자기관에 홍보할 기회를 얻기 힘든 1인 미디어 스타트업들의 민간 투자유치를 지원할 목적으로 마련됐다.
# 상온에 음식 오래 두지 말라고. 여름에는.
# 냉장고 안에 있는 내용물 어떻게 확인해?
# 이와 함께 정부는 데이터 분야 스타트업을 발굴 육성하고, 우수 데이터 활용 스타트업을 대상으로 데이터 특화 컨설팅 및 투자유치 등 실질적 지원을 확대한다.
# 화장실 수납장을 열면 정화조 냄새가 난다.
# 10조원 규모의 SPV는 산업은행이 세우고 한국은행이 SPV에 8조원을 선순위로 직접 대출한다.
# 광고 메일의 토픽 들 중 가장 많은 부분을 차지하고 있던 것은?
# 나머지는 사진이랑 비슷했던 것 같아요.
# 여행자에게  심리적으로 안정감을 줍니다
# 원격수업의 출결은 기존 등교 수업처럼 각 교과 담당 교사가 수업 당일 기준으로 확인해 출석부에 ‘출석’ 또는 ‘결석(결과)’으로만 처리한다.
# 전기요금 감면은 내달 1일부터 9월 30일까지 신청할 수 있고, 4월 18일부터 소비자가 받을 청구서(납부기한 4월 25일)상 당월 사용요금에 적용된다.
# 늦은 시각에도 체크인을 할 수 있도록 도움을 주신 호스트에게 감사드립니다.
# 서비스는 단순 안부확인·가사 지원 등에서 안전, 건강, 사회참여 등으로 다양화하며 대상도 35만명 독거노인에서 45만명의 돌봄 필요 노인으로 확대한다.
# 아침마다 화장실에서 나는 하수구 냄새 때문에 힘들었네요.
# 아쉬웠던 점은 우선 역에서는 조금 멀기 때문에 버스를 타야한다.
# 아테네 시내 웬만한 호텔보다 가성비 좋은 숙소였습니다.
# 같이 못 들어가면 만나기 어려우니까 야구경기 약속에 늦지 말거라.
# 스트립까지 걸어갈 수 있다는 점이 진짜 큰 장점인거 같아요!
# 슬플 때 참지 말고 빗속을 달려볼 것.
# 깨끗하고 주변 식당이나 상점에 대한 접근성이 좋았음
# 누구라도 만족 할만한 좋은 숙소 입니다.
# 국내 기업의 자가용항공기(비사업용) 등록의 걸림돌로 지적된 외국인 지분제한 규정도 완화하기로 했다.
# 한편 행안부는 그동안 1차 48억원, 2차 157억 5000만원, 3차 25억원 등 총 230억 5000만원의 특교세를 지원했다.
# 특히 특수교사들의 원격수업을 지원하기 위해 4월 6일부터 국립특수교육원에 ‘장애학생 온라인 학습방(http://www.nise.go.kr)’을 운영한다.
# 단점은 다른분들이 후기 남기셨듯이 엘레베이터가 없는거랑 화장실이 밖에 있는거에요.
# 런던에 대한 색다른 추억을 선사해 줄 것으로 기대합니다.
# 벚꽃 축제로 유명한 도시는?
# 그 중에 이 장소가 가장 합리적이 가격에 시설, 서비스, 위치, 친절함 전부 맘에 들었습니다.
# 방은 호스트가 쓰던 안방을 내주는데 방이 큽니다.
# 씨비인사이트(CBinsights) 기준으로 미국·중국·영국·인도 등 유니콘기업수 상위 1~4위 국가 모두 복수의결권 제도를 운영 중이다.
# 호스트의 초코릿 선물에 저희아기들이 행복했답니다.
# 국립청소년수련원(평창)에 디지털 체험관을 시범 운영하는 등 변화하는 디지털 환경에 맞게 청소년활동 시설과 프로그램을 개선한다.
# 가습기 계속 켜둬
# 이에 따라 이미 사내근로복지기금(이하 ‘사내기금’)이 있는 대기업(원청)이 중소 협력업체들과 공동기금을 새로 설립할 경우 대기업(원청)의 사내기금 해산이 허용된다.
# 리스본에서 묶을 수 있는 숙소 중 가장 좋은거 같습니다.
# 어떻게 하면 보일러 모드를 설정할 수 있지?
# 이 과정에서 모든 창의적인 방법들이 동원되었습니다.
# 단점 건물 자체에 엘리베이터가 굉장히 좁습니다
# 어떤 거를 시장에서 사올거니?
# 비옷은 안되니까 우산 챙겨가.
# 방은 생각보다 작았지만 1층에 어떤 방은 꽤 큽니다.
# 테르미니 주변은 위험하다는 얘기가 많은데요
# 결혼이주여성에게는 역량강화와 취업연계 등을 위한 자립지원패키지를 지난해 183개에서 올해 196개로 확대하고, 3월부터 ‘맞춤형 한국어교육 프로그램’을 신규로 운영한다.
# 내일 불쾌지수가 육십보다 높을지 낮을지 알려주십시오.
# 거실에서 계단으로 내려가면 방이 있는 구조입니다.
# 천둥과 번개 중 무서워하는 것을 골라주십시오.
# 얼마나 되나요? 현재까지 서울의 강수량은.
# 시내 중심까지도 충분히 걸어다닐 위치입니다.
# 겨울에 난방 온도를 이십오도 이하로 유지하자
# 주변 반경으로 편의시설 및 나메구역도 엄청가까워요!
# 너는 선풍기 바람 회전이랑 고정 중 어느걸 켜고 싶어?
# 규제 샌드박스, 강원·대구 규제자유특구를 활용한 실증연구와 해외시장 진출도 적극 지원하기로 했다.
# 이번주하고 다음주 중에 농구를 언제 더 많이 한 것 같아?
# 모든게 만족스러운 비앤비라 렌트카 여행하는 한국인 모두에게 추천합니다.
# 본섬가는 버스 자주있고, 운행 24시간한대요.
# 따뜻한물도 잘나와요 ! 교통편도 좋았어요
# 아침 저녁으로 테라스에 비둘기 손님이 앉았다
# 앞으로 어른들과 만나는 자리에는 잊지 말고 일찍 나가 있기로 해.
# 또 백신 항원 전달체와 불활화 백신 등 다양한 형태의 백신을 개발할 계획이다.
# 사진에 보이는 것처럼 오페라 하우스와 하버브릿지가 보여서 뷰가 환상적 입니다.
# 다만 토요일 밤 새벽내내 윗집에서 내뿜는 소음때문에 잠을 설쳤는데요.
# 스포츠기업 지원 사업 대상으로 피해 기업 우선 선발
# 오픈뱅킹 참여 핀테크기업은 자체점검에 더해 보안점검기관을 통한 외부 보안점검을 의무화한다.
# 서역에서 도보 5분 거리에 위치하여 중심가, 주요관광지로의 이동이 수월합니다.
# 사소한 배려들이 너무 감동적이었습니다.
# 로마의 정취가 물씬 풍겨나는 매력적인 골목길에 위치한 이 멋진 집은, 그 집보다도 더 훌륭한 호스트가 여러분을 반길 것입니다.
# 그리고 문단속 철저히 하기를 요구하는데 열쇠사용법이 좀 까다로웠습니다.
# 형편이 되는 만큼 뜻이 있는 만큼 참여해 주시기 바랍니다.
# 세계 최초 5세대 이동통신(5G) 상용화가 1년을 맞았다.
# 여행에 필요한 모든것이 완벽한 숙소입니다
# 더운물보단 미지근한 물로 목욕해야해
# 다음에 언젠가 로마에 다시오면 이 곳에서 지낼 생각입니다.
# 자외선 수치는 낮 동안 어떻습니까? 동경 지역의.
# 여름에는 더운 낮에 만나지 말고 선선한 저녁에 보기로 하자.
# 해외규격인증획득 지원대상 확대, 해외환경통합정보망을 통한 현지 정보제공, 중기부 수출지원사업 우대 등 세계시장 진출 지원 프로그램도 더욱 강화할 계획이다.
# 호스트는 정말 친철하고 연락도 잘됩니다!
# 정원에서는 그네와 월풀을 이용가능하고 바베큐도 가능한 것으로 보입니다.
# 이런점들 빼면 모든게 완벽한 숙소입니다.
# 잘못된 정보를 보내지 않도록 메일 발송 전 반드시 두 번은 검토를 해야 합니다.
# 삼십 대 네이버 메일 유저 수를 알려줘
# 게다가 정말 또박또박 천천히 이야기해줍니다.
# 숙소가 정말 깨끗하고 온수도 잘나옵니다.
# 위치도 정말 여행하기 딱 좋은 위치에있습니다!
# 숙소에서 바로 건너편에 유기농 마트가 있어요.
# 너희 집 부모님 가스레인지 한달 비용이 얼마이니?
# 하지만 다시 더블린을 간다면 또 나는 여기서 묵을것입니다.
# 청약신청은 한국토지주택공사, 서울주택도시공사, 경기주택도시공사 등 공공주택사업자별 입주자모집 공고를 확인한 후 누리집 또는 현장접수 등으로 가능하다.
# 이런 집은 에어비앤비에서 찾을 수 없어야 합니다.
# 주방기구 및 침구류 등의 위생상태도 최고 였습니다.
# 집안 내 침대와 가구들도 전체적으로 깨끗했었고요.
# 집 자체 시설과 물놀이 용품등이 구비되었는점은 좋았습니다
# 너는 서재 조명등 밝기 이단계랑 삼단계 모드 중에 어느거 켜는게 더 좋을 것 같아?
# 나는 한적한 곳을 좋아하기에 매우 만족했습니다.
# 여름철 실내온도 너무 낮게 두지마.
# 알려줘. 한국 단풍 명소.
# 일본은 지난해 7월 반도체·디스플레이 핵심 소재인 불화수소, 플루오린 폴리이미드, 포토레지스트의 대(對)한국 수출제한 조치를 단행했다.
# 전망좋은 발코니에서 편안히 바다를 즐겼습니다.
# 관광지가 몰려있는 세비야 대성당쪽이 아닌 메트로폴 파라솔 인근에 위치한 아파트예요.
# 오늘 저녁 축구 경기 몇 시죠?
# 그리고 집 열쇠를 가지고 다닐 필요가 없는 점도 편합니다.
# 티비 보면 안 돼!
# 뿐만 아니라 주변 교통상황과 관광지등 친절한 소개에 감사한다.
# 부모님이랑 이번 주에 만나기로 한게 언제지?
# 화장실 세면대가 진짜 생각하시는거 이상으로 작아요.
# 양산과 우산 중 네게 필요한게 뭐야?
# 지하철역에서 도보 1분거리이고 때르미니역 도보5분 콜로세움 도보20분 트레비분수 스페인광장도 도보15분 내외입니다.
# 엘리베이터가 약간 찾기 힘들 뿐이에요.
# 주요관광 명소인 달리 극장박물관과 장난감박물관이 정말 가까이에 있습니다.
# 완전 시내중심은 아니지만 버스로 충분히 이동 가능합니다.
# 대용량 파일 전송시 다른 메일들은 오류가 잦으니 네이버 메일을 추천할게
# 드럼 세탁기 조정 방법 좀 알려주세요
# 오늘과 내일 중에서 제 택배가 언제 오는지 아십니까?
# 무엇보다 유럽숙소치고 따뜻한 편입니다.
# 혹시 늦게 된다면 연락을 안하기 보다는 미리 그 이유를 알려줘.
# 위치 아주좋고, 숙소도 사진 그대로 아주 깔끔해요.
# 에어컨,냉장고,세탁기,전자렌지,수저, 화장지2개,수건1인2개, 있어요
# 욕실 물도 따뜻한물 수압좋은상태로 잘 나오구요.
# 또 새로운 스마트 공장을 준비 중인 기업에 대해선 설비 전문가도 파견한다.
# 텝스 시험은 다음주 금요일에 있어, 토요일에 있어?
# 다만 건강보험 가입자의 피부양자로 등록된 배우자와 자녀는 주소지를 달리하더라도 동일가구로 인정한다.
# 대체적으로 우리 가족이 이용하기에는 좋은 점이 더 많았습니다
# 한돈 온라인 공식 쇼핑몰인 한돈몰에서는 ‘2020 코리아세일페스타! 한돈 보쌈 한 쌈’이라는 이름으로 11월 27일까지 기획전이 진행 중이다.
# 오늘 5차 비상경제회의에서는 기간산업의 위기와 고용 충격에 신속히 대처하고, 국민의 일자리를 지키기 위한 특단의 대책을 결정합니다.
# 파티오는 그 주위에 있는 집들 중에 가장 아름다웠습니다.
# 총 몇 번의 약속이 다음주에 잡혀 있나요?
# 이 부분만 감안하면 최고의 숙소임이 분명합니다.
# 숙소 바로 앞에 지하철역이 있어서 이동하기 수월합니다.
# 이들은 3월 3일 졸업 및 임관식을 마친 뒤 곧바로 국군대구병원으로 향했다.
# 단풍으로는 어느 산이 유명합니까?
# 1번이 이미 어마어마한 장점인데 심지어 위치가 호시우 광장에서 5분도 안 걸려요.
# 농업인의 날 기념식에 대통령이 참석한 것은 2003년 이후 17년 만이다.
# 실제로 집에는 아이들을 위한 장난감이 많이 있습니다.
# 지각해 놓고 변명을 해도 지각한 건 바뀌지 않으니 그러지 마라.
# 위치나 시설 모든 면에서 정말 최고의 숙소였습니다.
# 흰색으로 된 방이 되게 안정감을 주더라구요.
# 서쪽 런던에 위치한 1층집에서 호스트 분과 함께 거실을 쓰고 게스트는 큰 방을 씁니다.
# 찬물빨래 해야되는 세탁물들은 어떻게 알 수 있지
# 최근 방송한 국악 채널 검색하려면 어떻게 해야돼?
# 다음 메일은 최대 얼마까지 저장할 수 있나요?
# 숙소 안은 정말 깨끗하고 에어컨도 잘 나옵니다.
# 정크 메일 항목들을 쭉 알려줘
# 회사 상사와의 약속이니까 여유 부리지 말고 먼저 나가.
# 던 샌드위치와 빵은 정말 감동이었어요.
# 메일이랑 손편지 중 군인장병들한테 편한 소통 수단은 뭔가요?
# 삼월엔 다해서 몇 통의 메일을 받았지?
# 침실 무드등이 밝기가 얼마나 되는지 알려줘
# 지금 에어컨 희망온도가 몇도야?
# 처음 방에 들어섰을 때 따가운 가족들의 눈총을 받았지요.
# 헬스장에 아침에 가는거야 저녁에 가는거야?
# 남은 2년, 더욱 단단한 각오로 국정에 임하겠습니다.
# 전 세계 120여 개 국가의 문화 장관 및 차관, 고위급 인사들은 ‘코로나19 확산이 문화 분야에 미치는 영향’이라는 주제로 각국의 대책과 전략을 공유했다.
# 또 공동구매 전용보증을 통해 참여 기업의 구매대금이 올해 1360억원까지 보증된다.
# 돌봄포인트를 선택하신 경우 4월 23일(목) 지급할 계획이며, 기프트카드로 지급을 원하시는 경우 5월초 발송할 계획입니다.
# 이는 전일대비 총 130만 가구, 8349억원 증가한 수치다.
# 알려줘. 태풍이 발생되는 곳을.
# 근데 그부분은 다른 호텔도 비슷했어요.
# 공기 청정기 어떻게 쓰면 되는 거야?
# 캐리어를 펴고 닫을만한 공간도 충분합니다.
# 놀지 말고 일기예보 들읍시다. 바다에서는.
# 이해관계가 첨예한 사안에 대해서는 갈등조정 체계를 구축한다.
# 파리을 가족과 함께 여행하신다면, 기꺼이 추천합니다.
# 에어비앤비에서 제공하는 지도 위치는 실제와 다른곳이에요
# 덕분에 아테네가 좋은 기억으로 남을것이다.
# 지난달 하루 평균 수출액이 전년대비 5.6% 증가한 가운데 자동차는 2017년 11월 이후 처음으로 수출액이 40억 달러를 돌파했다.
# 나쁜 생각은 하지 말고 긍정적인 생각해요. 불쾌지수 높을 때는.
# 전자레인지 한 달동안 총 사용 시간 알려줄래
# 추운날이니 외출은 자제해주시기 바랍니다.
# 그리고 호스트 부부가 모두 영어를 구사해 의사소통에도 별 문제가 없는 편입니다.
# 역에서 찾아가기 쉽고 정말 도보 10분 거리예요.
# 몇 월 며칠이 남자친구 생일이야?
# 로열 요트 브리태니아나 그 근방 부근의 관광도 무리없이 할 수 있습니다.
# 전철역도보3분 기차역도보8분정도 교통 좋았어요
# 다만, 침구류의 머리카락은 조금 아쉬웠다.
# 엄마 우리 건조기를 먼저 사야해요, 세탁기를 먼저 사야해요?
# 농림축산식품부는 지자체와 함께 식사문화 3대 개선과제를 실천하는 안심식당 총 1만 6000여 개소를 지정했다.
# 오히려 이후 이용한 호텔보다 더 좋았습니다.
# 집안 조명 밝기 정도 좀 바꾸고 싶은데 방법을 모르겠어 좀 알려줘
# 사모(모자) 모양의 봉형에 자리했으며 내외부를 모두 돌로 쌓은 협축식 산성으로 당시 군사적 거점과 함께 행정의 중심지로 꾸준히 활용됐던 것으로 보인다.
# 다만 중앙역까지는 조금 멀구 타는 정류장까지는 4분내로 갑니다!

# %%
adverb_augset = pd.concat([orig_train, sen1_adverb_train, sen2_adverb_train])
adverb_augset.drop_duplicates(['sentence1', 'sentence2'], inplace=True)
len(adverb_augset)

# %%
adverb_augset.reset_index().to_json('sts/datasets/klue-sts-v1.1_train_adverb_augset.json')

# %% [markdown]
# ## 기존 EDA 방법 (KorEDA)
# - random_delete
# - random_swap
# - synonym_replacement
# - random_insert

# %%
from koreda import synonym_replacement, random_deletion, random_swap, random_insertion

# %%
ex = '안녕하세요. 이것은 매우 간단한 예문입니다.'
print(synonym_replacemnt(ex, 1))
print(random_deletion(ex, 1))
print(random_swap(ex, 1))
print(random_insertion(ex, 1))

# %%
# synonym_replacement
sen1_sr_train = orig_train.copy()
sen2_sr_train = orig_train.copy()
sen1_sr_train['sentence1'] = sen1_sr_train['sentence1'].apply(lambda x: " ".join(synonym_replacement(x)))
sen2_sr_train['sentence2'] = sen2_sr_train['sentence2'].apply(lambda x: " ".join(synonym_replacement(x)))

# %%
sr_augset = pd.concat([orig_train, sen1_sr_train, sen2_sr_train])
sr_augset.drop_duplicates(['sentence1', 'sentence2'], inplace=True)
len(sr_augset)

# %%
sr_augset.reset_index().to_json('sts/datasets/klue-sts-v1.1_train_sr_augset.json')

# %%
# random_deletion
sen1_rd_train = orig_train.copy()
sen2_rd_train = orig_train.copy()
sen1_rd_train['sentence1'] = sen1_rd_train['sentence1'].apply(lambda x: " ".join(random_deletion(x)))
sen2_rd_train['sentence2'] = sen2_rd_train['sentence2'].apply(lambda x: " ".join(random_deletion(x)))

# %%
rd_augset = pd.concat([orig_train, sen1_rd_train, sen2_rd_train])
rd_augset.drop_duplicates(['sentence1', 'sentence2'], inplace=True)
len(rd_augset)

# %%
rd_augset.reset_index().to_json('sts/datasets/klue-sts-v1.1_train_rd_augset.json')

# %%
# random_swap
sen1_rs_train = orig_train.copy()
sen2_rs_train = orig_train.copy()
sen1_rs_train['sentence1'] = sen1_rs_train['sentence1'].apply(lambda x: " ".join(random_swap(x)))
sen2_rs_train['sentence2'] = sen2_rs_train['sentence2'].apply(lambda x: " ".join(random_swap(x)))

# %%
rs_augset = pd.concat([orig_train, sen1_rs_train, sen2_rs_train])
rs_augset.drop_duplicates(['sentence1', 'sentence2'], inplace=True)
len(rs_augset)

# %%
rs_augset.reset_index().to_json('sts/datasets/klue-sts-v1.1_train_rs_augset.json')

# %%
# random_insertion
sen1_ri_train = orig_train.copy()
sen2_ri_train = orig_train.copy()
sen1_ri_train['sentence1'] = sen1_ri_train['sentence1'].apply(lambda x: " ".join(random_insertion(x)))
sen2_ri_train['sentence2'] = sen2_ri_train['sentence2'].apply(lambda x: " ".join(random_insertion(x)))

# %%
ri_augset = pd.concat([orig_train, sen1_ri_train, sen2_ri_train])
ri_augset.drop_duplicates(['sentence1', 'sentence2'], inplace=True)
len(ri_augset)

# %%
ri_augset.reset_index().to_json('sts/datasets/klue-sts-v1.1_train_ri_augset.json')
